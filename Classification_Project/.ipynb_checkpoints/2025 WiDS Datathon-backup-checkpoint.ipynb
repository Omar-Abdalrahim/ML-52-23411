# %% [markdown]
# # WiDS Datathon 2025
#
# The goal is to build a model to predict both an individual’s sex and their ADHD diagnosis using functional brain imaging data of children and adolescents and their socio-demographic, emotions, and parenting information. https://www.kaggle.com/competitions/widsdatathon2025/overview
#
# **Dataset Folders**\
# (1) the training folder train_new_tsv consists of three types of information about the 1,200+ subjects. They are:
#
# a) the targets (ADHD diagnosis and sex)\
# b) functional MRI connectome matrices\
# c) socio-demographic information, e.g., subject’s “handedness” or “parent’s education level”, emotions (“Strength and Difficulties Questionnaire”), and parenting information (“Alabama Parenting Questionnaire”). These include both quantitative and categorical metadata.
#
# **Friendly hint**: Participants will need to process the categorical data (perhaps create dummy variables) and then combine this processed dataset with the functional connectome dataset to create a final training dataset to use in their models.
#
# (2) the test folder test_tsv consists of unseen data frames for 300+ subjects. These data frames are as follows:
#
# a) functional MRI connectome matrices\
# b) socio-demographic, emotions, and parenting information
#
# **Target Variables**\
# ADHD_Outcome: Type of Diagnosis (0=Other/None, 1=ADHD)\
# Sex_F: Sex of participant (0=Male, 1=Female)

# %% [markdown]
# ##### imports

# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn.preprocessing as prep
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots 

import sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, accuracy_score

# %% [markdown]
# ##### Helper Functions

# %%
def get_messing(df,drop=False):
    missing_data = pd.DataFrame({'Count': df.isnull().sum(),
                            '%':(df.isnull().sum()/df.shape[0]*100 ).round(2)
                            })
    if (missing_data[missing_data != 0].dropna().sum().sum() == 0) :
        print("No Messing Data")
    else : 
        if drop :
            return(missing_data[missing_data != 0].dropna())
        else: return(missing_data)

# %%
def handel_Outliers(df,Outlier_columns,handel = True):
    for col in Outlier_columns:
        print(col," : \n")
        # first get the IQR value then apply the rule
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        print(f"IQR = {IQR}")
        # Anything above the upper limit or lower than the lower limit is an outlier
        cut_off = IQR * 1.5
        lower = Q1 - cut_off
        upper =  Q3 + cut_off
        print(f"lower,upper bounds [{lower},{upper}]")
        
        u = df[df[col]> upper]
        l = df[df[col] < lower]
        print(F'Total number of outliers in {col} are {u.shape[0]+ l.shape[0]}')
        if handel:
            df.loc[df[col] < lower, col] = df[col].median()
            df.loc[df[col] > upper, col] = df[col].median()
        print("===========================================")   
    if handel:
        print("All ouliers Handeled successfully")

    return df

# %%
def multi_output_accuracy(y_true, y_pred):
    # Ensure y_true and y_pred are NumPy arrays
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    # Compute accuracy for each target variable and return the mean
    return np.mean([accuracy_score(y_true[:, i], y_pred[:, i]) for i in range(y_true.shape[1])])

# Create a scorer using scikit-learn's make_scorer
multi_output_scorer = make_scorer(multi_output_accuracy, greater_is_better=True)

# %% [markdown]
# # Load Data

# %%
# Train data
TRAIN_CATEGORICAL = pd.read_excel("TRAIN_NEW/TRAIN_CATEGORICAL_METADATA_new.xlsx")
TRAIN_FUNCTIONAL_CONNECTOME_MATRICES = pd.read_csv("TRAIN_NEW/TRAIN_FUNCTIONAL_CONNECTOME_MATRICES_new_36P_Pearson.csv")
TRAIN_QUANTITATIVE = pd.read_excel("TRAIN_NEW/TRAIN_QUANTITATIVE_METADATA_new.xlsx")
TRAINING_SOLUTIONS = pd.read_excel("TRAIN_NEW/TRAINING_SOLUTIONS.xlsx")

# %%
# Test data
TEST_CATEGORICAL = pd.read_excel("TEST/TEST_CATEGORICAL.xlsx")
TEST_FUNCTIONAL_CONNECTOME_MATRICES = pd.read_csv("TEST/TEST_FUNCTIONAL_CONNECTOME_MATRICES.csv")
TEST_QUANTITATIVE_METADATA = pd.read_excel("TEST/TEST_QUANTITATIVE_METADATA.xlsx")

# %% [markdown]
# # EDA

# %%
id1 = TRAIN_CATEGORICAL.participant_id.sort_values().reset_index(drop=True)
id2 = TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.participant_id.sort_values().reset_index(drop=True)
id3 = TRAIN_QUANTITATIVE.participant_id.sort_values().reset_index(drop=True)

(id1.equals(id2)) and (id1.equals(id3))
# Out:
# True

# %% [markdown]
# All ids refer to the same persons

# %%
TRAIN_CATEGORICAL = TRAIN_CATEGORICAL.sort_values('participant_id').reset_index(drop=True)
TRAIN_FUNCTIONAL_CONNECTOME_MATRICES = TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.sort_values('participant_id').reset_index(drop=True)
TRAIN_QUANTITATIVE = TRAIN_QUANTITATIVE.sort_values('participant_id').reset_index(drop=True)
TRAINING_SOLUTIONS = TRAINING_SOLUTIONS.sort_values('participant_id').reset_index(drop=True)

# %% [markdown]
# ## TRAINING_SOLUTIONS

# %%
TRAINING_SOLUTIONS.head()
# Out:
#   participant_id  ADHD_Outcome  Sex_F
# 0   00aIpNTbG5uh             1      0
# 1   00fV0OyyoLfw             1      0
# 2   04X1eiS79T4B             0      1
# 3   05ocQutkURd6             0      1
# 4   06YUNBA9ZRLq             1      0

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# Create the subplot figure
fig = make_subplots(
    rows=1, cols=2,
    column_widths=[0.5, 0.5],
    specs=[[{"type": "domain"}, {"type": "domain"}]],
    subplot_titles=["Distribution of ADHD_Outcome", "Sex Distribution"]
)

df = TRAINING_SOLUTIONS.select_dtypes(include=['float64', 'int64'])

# Pie chart for ADHD_Outcome (1 = Has, 0 = No ADHD)
counts = df['ADHD_Outcome'].value_counts()
labels = ['Has ADHD' if val == 1 else 'No ADHD' for val in counts.index]
percentages = counts / counts.sum() * 100
label_with_pct = [f'{label} ({pct:.1f}%)' for label, pct in zip(labels, percentages)]

fig.add_trace(
    go.Pie(
        labels=label_with_pct,
        values=counts.values,
    ),
    row=1, col=1
)

# Pie chart for Sex_F (1 = Female, 0 = Male)
counts = df['Sex_F'].value_counts()
labels = ['Female' if val == 1 else 'Male' for val in counts.index]
percentages = counts / counts.sum() * 100
label_with_pct = [f'{label} ({pct:.1f}%)' for label, pct in zip(labels, percentages)]

fig.add_trace(
    go.Pie(
        labels=label_with_pct,
        values=counts.values,
    ),
    row=1, col=2
)

# Update layout
fig.update_layout(
    title_text="ADHD Outcome Distribution and Sex Breakdown",
    height=400
)

fig.show()
# Out:
# <div>                            <div id="adf9eb45-4de2-4318-a868-ed36f689a3c6" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("adf9eb45-4de2-4318-a868-ed36f689a3c6")) {                    Plotly.newPlot(                        "adf9eb45-4de2-4318-a868-ed36f689a3c6",                        [{"labels":["Has ADHD (68.5%)","No ADHD (31.5%)"],"values":[831,382],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.0,1.0]}},{"labels":["Male (65.7%)","Female (34.3%)"],"values":[797,416],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"s ...

# %% [markdown]
# ## TRAIN_CATEGORICAL

# %%
TRAIN_CATEGORICAL.head()
# Out:
#   participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 0   00aIpNTbG5uh                     2019                       4
# 1   00fV0OyyoLfw                     2017                       1
# 2   04X1eiS79T4B                     2017                       1
# 3   05ocQutkURd6                     2018                       1
# 4   06YUNBA9ZRLq                     2018                       1
#
#    PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 0                               1.0                          0.0
# 1                               0.0                          9.0
# 2                               1.0                          2.0
# 3                               3.0                          8.0
# 4                               0.0                          1.0
#
#    MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  Barratt_Barratt_P1_Occ  \
# 0                      3.0                    21.0                    45.0
# 1                      2.0                    21.0                     0.0
# 2                      2.0                     9.0                     0.0
# 3                      2.0                    18.0                    10.0
# 4                      2.0                    12.0                     0.0
#
#    Barratt_Barratt_P2_Edu  Barratt_Barratt_P2_Occ
# 0                     NaN                     NaN
# 1                    21.0                    45.0
# 2                     NaN                     NaN
# 3                    18.0                     0.0
# 4                     NaN                     NaN

# %%
TRAIN_CATEGORICAL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1213 entries, 0 to 1212
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   participant_id                    1213 non-null   object
#  1   Basic_Demos_Enroll_Year           1213 non-null   int64
#  2   Basic_Demos_Study_Site            1213 non-null   int64
#  3   PreInt_Demos_Fam_Child_Ethnicity  1170 non-null   float64
#  4   PreInt_Demos_Fam_Child_Race       1159 non-null   float64
#  5   MRI_Track_Scan_Location           1210 non-null   float64
#  6   Barratt_Barratt_P1_Edu            1198 non-null   float64
#  7   Barratt_Barratt_P1_Occ            1182 non-null   float64
#  8   Barratt_Barratt_P2_Edu            1015 non-null   float64
#  9   Barratt_Barratt_P2_Occ            991 non-null    float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 94.9+ KB

# %%
TRAIN_CATEGORICAL.describe()
# Out:
#        Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# count              1213.000000             1213.000000
# mean               2017.652102                2.014839
# std                   1.122522                1.135147
# min                2015.000000                1.000000
# 25%                2017.000000                1.000000
# 50%                2018.000000                1.000000
# 75%                2019.000000                3.000000
# max                2020.000000                4.000000
#
#        PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# count                       1170.000000                  1159.000000
# mean                           0.435897                     2.177739
# std                            0.693174                     3.204782
# min                            0.000000                     0.000000
# 25%                            0.000000                     0.000000
# 50%                            0.000000                     1.000000
# 75%                            1.000000                     2.000000
# max                            3.000000                    11.000000
#
#        MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  \
# count              1210.000000             1198.000000
# mean                  2.294215               17.862270
# std                   0.750660                3.505608
# min                   1.000000                3.000000
# 25%                   2.000000               15.000000
# 50%                   2.000000               18.000000
# 75%                   3.000000               21.000000
# max                   4.000000               21.000000
#
#        Barratt_Barratt_P1_Occ  Barratt_Barratt_P2_Edu  Barratt_Barratt_P2_Occ
# count             1182.000000             1015.000000              991.000000
# mean                25.545685               16.876847               30.257316
# std                 16.757043                3.929558               13.901144
# min                  0.000000                3.000000                0.000000
# 25%                  5.000000               15.000000               20.000000
# 50%                 30.000000               18.000000               35.000000
# 75%                 40.000000               21.000000               40.000000
# max                 45.000000               21.000000               45.000000

# %%
for col in TRAIN_CATEGORICAL.columns:
    print(f"{col}: {TRAIN_CATEGORICAL[col].unique()}")
# Out:
# participant_id: ['00aIpNTbG5uh' '00fV0OyyoLfw' '04X1eiS79T4B' ... 'zwBG0rZ05Mcb'
#  'zwXD5v17Rx01' 'zwjJWCRzKhDz']
# Basic_Demos_Enroll_Year: [2019 2017 2018 2016 2015 2020]
# Basic_Demos_Study_Site: [4 1 2 3]
# PreInt_Demos_Fam_Child_Ethnicity: [ 1.  0.  3.  2. nan]
# PreInt_Demos_Fam_Child_Race: [ 0.  9.  2.  8.  1. 10.  4. nan  3. 11.  7.]
# MRI_Track_Scan_Location: [ 3.  2.  1.  4. nan]
# Barratt_Barratt_P1_Edu: [21.  9. 18. 12. 15.  3. nan  6.]
# Barratt_Barratt_P1_Occ: [45.  0. 10. 35. 40. 25. nan 30. 15.  5. 20.]
# Barratt_Barratt_P2_Edu: [nan 21. 18. 15. 12.  9.  6.  3.]
# Barratt_Barratt_P2_Occ: [nan 45.  0. 30. 40. 15. 35.  5. 10. 20. 25.]

# %%
get_messing(TRAIN_CATEGORICAL)
# Out:
#                                   Count      %
# participant_id                        0   0.00
# Basic_Demos_Enroll_Year               0   0.00
# Basic_Demos_Study_Site                0   0.00
# PreInt_Demos_Fam_Child_Ethnicity     43   3.54
# PreInt_Demos_Fam_Child_Race          54   4.45
# MRI_Track_Scan_Location               3   0.25
# Barratt_Barratt_P1_Edu               15   1.24
# Barratt_Barratt_P1_Occ               31   2.56
# Barratt_Barratt_P2_Edu              198  16.32
# Barratt_Barratt_P2_Occ              222  18.30

# %%
merged_df = pd.merge(TRAIN_CATEGORICAL, TRAINING_SOLUTIONS, on='participant_id', how='inner')
merged_df.head()
# Out:
#   participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 0   00aIpNTbG5uh                     2019                       4
# 1   00fV0OyyoLfw                     2017                       1
# 2   04X1eiS79T4B                     2017                       1
# 3   05ocQutkURd6                     2018                       1
# 4   06YUNBA9ZRLq                     2018                       1
#
#    PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 0                               1.0                          0.0
# 1                               0.0                          9.0
# 2                               1.0                          2.0
# 3                               3.0                          8.0
# 4                               0.0                          1.0
#
#    MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  Barratt_Barratt_P1_Occ  \
# 0                      3.0                    21.0                    45.0
# 1                      2.0                    21.0                     0.0
# 2                      2.0                     9.0                     0.0
# 3                      2.0                    18.0                    10.0
# 4                      2.0                    12.0                     0.0
#
#    Barratt_Barratt_P2_Edu  Barratt_Barratt_P2_Occ  ADHD_Outcome  Sex_F
# 0                     NaN                     NaN             1      0
# 1                    21.0                    45.0             1      0
# 2                     NaN                     NaN             0      1
# 3                    18.0                     0.0             0      1
# 4                     NaN                     NaN             1      0

# %%
corr=merged_df.drop(['participant_id'],axis=1).corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of TRAIN_QUANTITATIVE")
plt.show()

# %%
# Extract correlations of features with respect to 'ADHD_Outcome'
correlation_with_sex = corr['ADHD_Outcome'].drop('ADHD_Outcome').sort_values(ascending=False)

# Plot the correlations
plt.figure(figsize=(10, 6))
sns.barplot(x=correlation_with_sex.index, y=correlation_with_sex.values, palette="coolwarm")
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel("Correlation with ADHD_Outcome")
plt.title("Feature Correlations with Sex (ADHD_Outcome)")
plt.show()

# %%
# Extract correlations of features with respect to 'Sex_F'
correlation_with_sex = corr['Sex_F'].drop('Sex_F').sort_values(ascending=False)

# Plot the correlations
plt.figure(figsize=(10, 6))
sns.barplot(x=correlation_with_sex.index, y=correlation_with_sex.values, palette="coolwarm")
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel("Correlation with Sex_F")
plt.title("Feature Correlations with Sex (Sex_F)")
plt.show()

# %% [markdown]
# ### Distribution of columns

# %%
numeric_df = TRAIN_CATEGORICAL.select_dtypes(include=['float64', 'int64'])
num_columns = len(numeric_df.columns)

# Create one subplot per numeric column
fig, axes = plt.subplots(num_columns, 1, figsize=(10, num_columns * 3))

for i, column in enumerate(numeric_df.columns):
    sns.histplot(numeric_df[column], ax=axes[i], kde=True)
    axes[i].set_title(f'Distribution of {column}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## TRAIN_FUNCTIONAL_CONNECTOME_MATRICES
#
# Functional connectivity matrices are always square and symmetric, corresponding to the
# number of regions of interest being used in a given anatomical atlas. For instance, using a 100
# region atlas, the functional connectivity matrix would have a shape of 100x100, where each
# value corresponds to the connectivity among that individual pair. For this challenge, you will be
# provided with 200 x 200 connectivity matrices.

# %%
TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.sort_values('participant_id').head()
# Out:
#   participant_id  0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  \
# 0   00aIpNTbG5uh          0.361339          0.791402          0.530706
# 1   00fV0OyyoLfw          0.051430          0.613198          0.635255
# 2   04X1eiS79T4B         -0.305747          0.750316         -0.005342
# 3   05ocQutkURd6          0.450442          0.731530          0.799147
# 4   06YUNBA9ZRLq          0.415220          0.585700          0.355835
#
#    0throw_4thcolumn  0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  \
# 0          0.623133          0.845830          0.680234          0.537144
# 1          0.391237          0.451225          0.600475          0.420935
# 2          0.458421          0.757530          0.756288          0.799046
# 3          0.701688          0.747468          0.523304          0.575033
# 4          0.664142          0.683491          0.380201          0.375091
#
#    0throw_8thcolumn  0throw_9thcolumn  ...  195throw_196thcolumn  \
# 0          0.387455          0.498571  ...             -0.047477
# 1          0.234825          0.322048  ...             -0.143218
# 2          0.622567          0.659165  ...             -0.133778
# 3          0.187189          0.441150  ...             -0.096647
# 4          0.212314          0.445294  ...             -0.158995
#
#    195throw_197thcolumn  195throw_198thcolumn  195throw_199thcolumn  \
# 0             -0.096450             -0.280312              0.037560
# 1             -0.276464             -0.332783             -0.332711
# 2             -0.108588             -0.002132             -0.175586
# 3             -0.041420             -0.199576             -0.216457
# 4             -0.274017             -0.141012             -0.002865
#
#    196throw_197thcolumn  196throw_198thcolumn  196throw_199thcolumn  \
# 0              0.423037              0.242453              0.336213
# 1              0.556939              0.475578              0.429196
# 2              0.679183              0.290292              0.486680
# 3              0.519074              0.298586              0.415466
# 4              0.515169              0.336139              0.316430
#
#    197throw_198thcolumn  197throw_199thcolumn  198throw_199thcolumn
# 0              0.402338              0.327915              0.539032
# 1              0.457970              0.312571              0.595978
# 2              0.255208              0.575017              0.605182
# 3              0.511607              0.361204              0.446613
# 4              0.442230              0.177079              0.378278
#
# [5 rows x 19901 columns]

# %%
TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1213 entries, 0 to 1212
# Columns: 19901 entries, participant_id to 198throw_199thcolumn
# dtypes: float64(19900), object(1)
# memory usage: 184.2+ MB

# %%
TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.drop('participant_id', axis=1).min().min()
# Out:
# -0.8753956628213888

# %%
TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.drop('participant_id', axis=1).max().max()
# Out:
# 0.9590231760120752

# %%
get_messing(TRAIN_FUNCTIONAL_CONNECTOME_MATRICES)
# Out:
# No Messing Data

# %% [markdown]
# - values ranges from -1 to 1 so no scaling will be needed.
# - Will obviously need some feature reduction later on (PCA).

# %% [markdown]
# ## TRAIN_QUANTITATIVE

# %%
TRAIN_QUANTITATIVE.head()
# Out:
#   participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0   00aIpNTbG5uh         100.00                  13.0             3.0
# 1   00fV0OyyoLfw          92.27                  14.0             3.0
# 2   04X1eiS79T4B          86.67                  14.0             3.0
# 3   05ocQutkURd6          93.34                  14.0             3.0
# 4   06YUNBA9ZRLq           0.00                  14.0             8.0
#
#    APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# 0            15.0             44.0             14.0            20.0
# 1            12.0             35.0             25.0            28.0
# 2            21.0             37.0             18.0            26.0
# 3            11.0             42.0             15.0            20.0
# 4            12.0             35.0             22.0            12.0
#
#    APQ_P_APQ_P_PP  SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Difficulties_Total  \
# 0            27.0                       3.0                        17.0
# 1            30.0                       5.0                        20.0
# 2            28.0                       3.0                        24.0
# 3            28.0                       0.0                         5.0
# 4            24.0                       6.0                        23.0
#
#    SDQ_SDQ_Emotional_Problems  SDQ_SDQ_Externalizing  \
# 0                         4.0                   11.0
# 1                         4.0                   13.0
# 2                         7.0                   10.0
# 3                         0.0                    3.0
# 4                         7.0                   15.0
#
#    SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  SDQ_SDQ_Internalizing  \
# 0                        5.0                    8.0                    6.0
# 1                        5.0                    8.0                    7.0
# 2                       10.0                    7.0                   14.0
# 3                        0.0                    3.0                    2.0
# 4                        8.0                    9.0                    8.0
#
#    SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial  MRI_Track_Age_at_Scan
# 0                    2.0                9.0              14.274127
# 1                    3.0                8.0                    NaN
# 2                    7.0                7.0              13.463381
# 3                    2.0                6.0               9.572553
# 4                    1.0                4.0               6.654574

# %%
TRAIN_QUANTITATIVE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1213 entries, 0 to 1212
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   participant_id              1213 non-null   object
#  1   EHQ_EHQ_Total               1200 non-null   float64
#  2   ColorVision_CV_Score        1190 non-null   float64
#  3   APQ_P_APQ_P_CP              1201 non-null   float64
#  4   APQ_P_APQ_P_ID              1201 non-null   float64
#  5   APQ_P_APQ_P_INV             1201 non-null   float64
#  6   APQ_P_APQ_P_OPD             1201 non-null   float64
#  7   APQ_P_APQ_P_PM              1201 non-null   float64
#  8   APQ_P_APQ_P_PP              1201 non-null   float64
#  9   SDQ_SDQ_Conduct_Problems    1204 non-null   float64
#  10  SDQ_SDQ_Difficulties_Total  1204 non-null   float64
#  11  SDQ_SDQ_Emotional_Problems  1204 non-null   float64
#  12  SDQ_SDQ_Externalizing       1204 non-null   float64
#  13  SDQ_SDQ_Generating_Impact   1204 non-null   float64
#  14  SDQ_SDQ_Hyperactivity       1204 non-null   float64
#  15  SDQ_SDQ_Internalizing       1204 non-null   float64
#  16  SDQ_SDQ_Peer_Problems       1204 non-null   float64
#  17  SDQ_SDQ_Prosocial           1204 non-null   float64
#  18  MRI_Track_Age_at_Scan       853 non-null    float64
# dtypes: float64(18), object(1)
# memory usage: 180.2+ KB

# %%
TRAIN_QUANTITATIVE.describe()
# Out:
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count    1200.000000           1190.000000     1201.000000     1201.000000
# mean       59.514750             13.419328        3.819317       13.337219
# std        49.744631              2.112830        1.330348        3.593562
# min      -100.000000              0.000000        2.000000        5.000000
# 25%        46.670000             14.000000        3.000000       11.000000
# 50%        77.800000             14.000000        3.000000       13.000000
# 75%        94.470000             14.000000        4.000000       16.000000
# max       100.000000             14.000000       12.000000       28.000000
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count      1201.000000      1201.000000     1201.000000     1201.000000
# mean         39.767694        17.963364       16.557036       25.498751
# std           4.872729         3.333965        5.146548        3.053720
# min          23.000000         7.000000        5.000000       13.000000
# 25%          36.000000        16.000000       13.000000       23.000000
# 50%          40.000000        18.000000       16.000000       26.000000
# 75%          43.000000        20.000000       19.000000       28.000000
# max          50.000000        28.000000       37.000000       30.000000
#
#        SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Difficulties_Total  \
# count               1204.000000                 1204.000000
# mean                   2.074751                   12.213455
# std                    2.022992                    6.517330
# min                    0.000000                    0.000000
# 25%                    0.000000                    7.000000
# 50%                    2.000000                   12.000000
# 75%                    3.000000                   17.000000
# max                   10.000000                   34.000000
#
#        SDQ_SDQ_Emotional_Problems  SDQ_SDQ_Externalizing  \
# count                 1204.000000            1204.000000
# mean                     2.324751               7.613787
# std                      2.166399               4.130399
# min                      0.000000               0.000000
# 25%                      1.000000               5.000000
# 50%                      2.000000               8.000000
# 75%                      4.000000              10.000000
# max                     10.000000              20.000000
#
#        SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  \
# count                1204.000000            1204.000000
# mean                    4.103821               5.539037
# std                     2.808079               2.807063
# min                     0.000000               0.000000
# 25%                     2.000000               4.000000
# 50%                     4.000000               6.000000
# 75%                     6.000000               8.000000
# max                    10.000000              10.000000
#
#        SDQ_SDQ_Internalizing  SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial  \
# count            1204.000000            1204.000000        1204.000000
# mean                4.599668               2.274917           7.740864
# std                 3.510469               2.089041           2.094832
# min                 0.000000               0.000000           0.000000
# 25%                 2.000000               0.000000           6.000000
# 50%                 4.000000               2.000000           8.000000
# 75%                 7.000000               4.000000          10.000000
# max                17.000000               9.000000          10.000000
#
#        MRI_Track_Age_at_Scan
# count             853.000000
# mean               11.245678
# std                 3.234372
# min                 0.000000
# 25%                 8.803901
# 50%                10.739219
# 75%                13.460871
# max                21.564453

# %%
get_messing(TRAIN_QUANTITATIVE)
# Out:
#                             Count      %
# participant_id                  0   0.00
# EHQ_EHQ_Total                  13   1.07
# ColorVision_CV_Score           23   1.90
# APQ_P_APQ_P_CP                 12   0.99
# APQ_P_APQ_P_ID                 12   0.99
# APQ_P_APQ_P_INV                12   0.99
# APQ_P_APQ_P_OPD                12   0.99
# APQ_P_APQ_P_PM                 12   0.99
# APQ_P_APQ_P_PP                 12   0.99
# SDQ_SDQ_Conduct_Problems        9   0.74
# SDQ_SDQ_Difficulties_Total      9   0.74
# SDQ_SDQ_Emotional_Problems      9   0.74
# SDQ_SDQ_Externalizing           9   0.74
# SDQ_SDQ_Generating_Impact       9   0.74
# SDQ_SDQ_Hyperactivity           9   0.74
# SDQ_SDQ_Internalizing           9   0.74
# SDQ_SDQ_Peer_Problems           9   0.74
# SDQ_SDQ_Prosocial               9   0.74
# MRI_Track_Age_at_Scan         360  29.68

# %%
merged_df = pd.merge(TRAIN_QUANTITATIVE, TRAINING_SOLUTIONS, on='participant_id', how='inner')
merged_df
# Out:
#      participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0      00aIpNTbG5uh         100.00                  13.0             3.0
# 1      00fV0OyyoLfw          92.27                  14.0             3.0
# 2      04X1eiS79T4B          86.67                  14.0             3.0
# 3      05ocQutkURd6          93.34                  14.0             3.0
# 4      06YUNBA9ZRLq           0.00                  14.0             8.0
# ...             ...            ...                   ...             ...
# 1208   zpU7rEseBMH8         100.00                  14.0             3.0
# 1209   zpr8w4jCfVPe         100.00                  14.0             3.0
# 1210   zwBG0rZ05Mcb          46.67                  13.0             3.0
# 1211   zwXD5v17Rx01          46.67                  14.0             3.0
# 1212   zwjJWCRzKhDz         100.00                  14.0             3.0
#
#       APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# 0               15.0             44.0             14.0            20.0
# 1               12.0             35.0             25.0            28.0
# 2               21.0             37.0             18.0            26.0
# 3               11.0             42.0             15.0            20.0
# 4               12.0             35.0             22.0            12.0
# ...              ...              ...              ...             ...
# 1208            11.0             41.0             16.0            23.0
# 1209             9.0             41.0             22.0            10.0
# 1210            12.0             30.0             18.0            14.0
# 1211            18.0             42.0             21.0            15.0
# 1212            14.0             36.0             18.0            13.0
#
#       APQ_P_APQ_P_PP  SDQ_SDQ_Conduct_Problems  ...  \
# 0               27.0                       3.0  ...
# 1               30.0                       5.0  ...
# 2               28.0                       3.0  ...
# 3               28.0                       0.0  ...
# 4               24.0                       6.0  ...
# ...              ...                       ...  ...
# 1208            24.0                       0.0  ...
# 1209            29.0                       1.0  ...
# 1210            24.0                       0.0  ...
# 1211            25.0                       2.0  ...
# 1212            22.0                       5.0  ...
#
#       SDQ_SDQ_Emotional_Problems  SDQ_SDQ_Externalizing  \
# 0                            4.0                   11.0
# 1                            4.0                   13.0
# 2                            7.0                   10.0
# 3                            0.0                    3.0
# 4                            7.0                   15.0
# ...                          ...                    ...
# 1208                         0.0                    6.0
# 1209                         3.0                    8.0
# 1210                         3.0                    5.0
# 1211                         0.0                    5.0
# 1212                         5.0                   13.0
#
#       SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  SDQ_SDQ_Internalizing  \
# 0                           5.0                    8.0                    6.0
# 1                           5.0                    8.0                    7.0
# 2                          10.0                    7.0                   14.0
# 3                           0.0                    3.0                    2.0
# 4                           8.0                    9.0                    8.0
# ...                         ...                    ...                    ...
# 1208                        6.0                    6.0                    2.0
# 1209                        3.0                    7.0                    7.0
# 1210                        3.0                    5.0                    5.0
# 1211                        0.0                    3.0                    0.0
# 1212                        5.0                    8.0                    7.0
#
#       SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial  MRI_Track_Age_at_Scan  \
# 0                       2.0                9.0              14.274127
# 1                       3.0                8.0                    NaN
# 2                       7.0                7.0              13.463381
# 3                       2.0                6.0               9.572553
# 4                       1.0                4.0               6.654574
# ...                     ...                ...                    ...
# 1208                    2.0                8.0              12.669860
# 1209                    4.0                7.0                    NaN
# 1210                    2.0                8.0               8.155258
# 1211                    0.0                7.0               7.364020
# 1212                    2.0                8.0              11.272986
#
#       ADHD_Outcome  Sex_F
# 0                1      0
# 1                1      0
# 2                0      1
# 3                0      1
# 4                1      0
# ...            ...    ...
# 1208             1      0
# 1209             1      0
# 1210             0      0
# 1211             1      0
# 1212             0      1
#
# [1213 rows x 21 columns]

# %%
corr = merged_df.drop(['participant_id'],axis=1).corr()
plt.figure(figsize=(15, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of TRAIN_QUANTITATIVE")
plt.show()

# %%
# Extract correlations of features with respect to 'ADHD_Outcome'
correlation_with_sex = corr['ADHD_Outcome'].drop('ADHD_Outcome').sort_values(ascending=False)

# Plot the correlations
plt.figure(figsize=(10, 6))
sns.barplot(x=correlation_with_sex.index, y=correlation_with_sex.values, palette="coolwarm")
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel("Correlation with ADHD_Outcome")
plt.title("Feature Correlations with Sex (ADHD_Outcome)")
plt.show()

# %%
# Extract correlations of features with respect to 'Sex_F'
correlation_with_sex = corr['Sex_F'].drop('Sex_F').sort_values(ascending=False)

# Plot the correlations
plt.figure(figsize=(10, 6))
sns.barplot(x=correlation_with_sex.index, y=correlation_with_sex.values, palette="coolwarm")
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel("Correlation with Sex_F")
plt.title("Feature Correlations with Sex (Sex_F)")
plt.show()

# %% [markdown]
# ### Distribution of Numeric column

# %%
numeric_df = TRAIN_QUANTITATIVE.select_dtypes(include=['float64', 'int64'])
num_columns = len(numeric_df.columns)  
fig, axes = plt.subplots(num_columns, 2, figsize=(12, num_columns * 4))  # 2 subplots (distribution and boxplot) for each column

for i, column in enumerate(numeric_df.columns):
    # Distribution Plot
    sns.histplot(numeric_df[column], ax=axes[i, 0], kde=True)  # kde=True adds a kernel density estimate (smoothed curve)
    axes[i, 0].set_title(f'Distribution of {column}')

    # Box Plot
    sns.boxplot(x=numeric_df[column], ax=axes[i, 1])
    axes[i, 1].set_title(f'Box Plot of {column}')

# Adjust layout to avoid overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## Missing data

# %% [markdown]
# ### TRAIN_QUANTITATIVE

# %%
get_messing(TRAIN_QUANTITATIVE)
# Out:
#                             Count      %
# participant_id                  0   0.00
# EHQ_EHQ_Total                  13   1.07
# ColorVision_CV_Score           23   1.90
# APQ_P_APQ_P_CP                 12   0.99
# APQ_P_APQ_P_ID                 12   0.99
# APQ_P_APQ_P_INV                12   0.99
# APQ_P_APQ_P_OPD                12   0.99
# APQ_P_APQ_P_PM                 12   0.99
# APQ_P_APQ_P_PP                 12   0.99
# SDQ_SDQ_Conduct_Problems        9   0.74
# SDQ_SDQ_Difficulties_Total      9   0.74
# SDQ_SDQ_Emotional_Problems      9   0.74
# SDQ_SDQ_Externalizing           9   0.74
# SDQ_SDQ_Generating_Impact       9   0.74
# SDQ_SDQ_Hyperactivity           9   0.74
# SDQ_SDQ_Internalizing           9   0.74
# SDQ_SDQ_Peer_Problems           9   0.74
# SDQ_SDQ_Prosocial               9   0.74
# MRI_Track_Age_at_Scan         360  29.68

# %% [markdown]
# Those are only the columns with missing data

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
import pandas as pd

# Step 1: Separate participant_id
ids = TRAIN_QUANTITATIVE['participant_id']
data = TRAIN_QUANTITATIVE.drop(columns=['participant_id'])

# Step 2: Scale and Impute
scaler = StandardScaler()
scaled = scaler.fit_transform(data)

imputer = KNNImputer(n_neighbors=5)
filled = imputer.fit_transform(scaled)

# Step 3: Reconstruct the DataFrame
data_imputed = pd.DataFrame(scaler.inverse_transform(filled), columns=data.columns)

# Step 4: Add participant_id back
TRAIN_QUANTITATIVE_imputed = pd.concat([ids.reset_index(drop=True), data_imputed], axis=1)
TRAIN_QUANTITATIVE_imputed
# Out:
#      participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0      00aIpNTbG5uh         100.00                  13.0             3.0
# 1      00fV0OyyoLfw          92.27                  14.0             3.0
# 2      04X1eiS79T4B          86.67                  14.0             3.0
# 3      05ocQutkURd6          93.34                  14.0             3.0
# 4      06YUNBA9ZRLq           0.00                  14.0             8.0
# ...             ...            ...                   ...             ...
# 1208   zpU7rEseBMH8         100.00                  14.0             3.0
# 1209   zpr8w4jCfVPe         100.00                  14.0             3.0
# 1210   zwBG0rZ05Mcb          46.67                  13.0             3.0
# 1211   zwXD5v17Rx01          46.67                  14.0             3.0
# 1212   zwjJWCRzKhDz         100.00                  14.0             3.0
#
#       APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# 0               15.0             44.0             14.0            20.0
# 1               12.0             35.0             25.0            28.0
# 2               21.0             37.0             18.0            26.0
# 3               11.0             42.0             15.0            20.0
# 4               12.0             35.0             22.0            12.0
# ...              ...              ...              ...             ...
# 1208            11.0             41.0             16.0            23.0
# 1209             9.0             41.0             22.0            10.0
# 1210            12.0             30.0             18.0            14.0
# 1211            18.0             42.0             21.0            15.0
# 1212            14.0             36.0             18.0            13.0
#
#       APQ_P_APQ_P_PP  SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Difficulties_Total  \
# 0               27.0                       3.0                        17.0
# 1               30.0                       5.0                        20.0
# 2               28.0                       3.0                        24.0
# 3               28.0                       0.0                         5.0
# 4               24.0                       6.0                        23.0
# ...              ...                       ...                         ...
# 1208            24.0                       0.0                         8.0
# 1209            29.0                       1.0                        15.0
# 1210            24.0                       0.0                        10.0
# 1211            25.0                       2.0                         5.0
# 1212            22.0                       5.0                        20.0
#
#       SDQ_SDQ_Emotional_Problems  SDQ_SDQ_Externalizing  \
# 0                   4.000000e+00                   11.0
# 1                   4.000000e+00                   13.0
# 2                   7.000000e+00                   10.0
# 3                  -4.440892e-16                    3.0
# 4                   7.000000e+00                   15.0
# ...                          ...                    ...
# 1208               -4.440892e-16                    6.0
# 1209                3.000000e+00                    8.0
# 1210                3.000000e+00                    5.0
# 1211               -4.440892e-16                    5.0
# 1212                5.000000e+00                   13.0
#
#       SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  SDQ_SDQ_Internalizing  \
# 0                           5.0                    8.0                    6.0
# 1                           5.0                    8.0                    7.0
# 2                          10.0                    7.0                   14.0
# 3                           0.0                    3.0                    2.0
# 4                           8.0                    9.0                    8.0
# ...                         ...                    ...                    ...
# 1208                        6.0                    6.0                    2.0
# 1209                        3.0                    7.0                    7.0
# 1210                        3.0                    5.0                    5.0
# 1211                        0.0                    3.0                    0.0
# 1212                        5.0                    8.0                    7.0
#
#       SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial  MRI_Track_Age_at_Scan
# 0                       2.0                9.0              14.274127
# 1                       3.0                8.0              13.340269
# 2                       7.0                7.0              13.463381
# 3                       2.0                6.0               9.572553
# 4                       1.0                4.0               6.654574
# ...                     ...                ...                    ...
# 1208                    2.0                8.0              12.669860
# 1209                    4.0                7.0               9.622815
# 1210                    2.0                8.0               8.155258
# 1211                    0.0                7.0               7.364020
# 1212                    2.0                8.0              11.272986
#
# [1213 rows x 19 columns]

# %%
TRAIN_QUANTITATIVE
# Out:
#      participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0      00aIpNTbG5uh         100.00                  13.0             3.0
# 1      00fV0OyyoLfw          92.27                  14.0             3.0
# 2      04X1eiS79T4B          86.67                  14.0             3.0
# 3      05ocQutkURd6          93.34                  14.0             3.0
# 4      06YUNBA9ZRLq           0.00                  14.0             8.0
# ...             ...            ...                   ...             ...
# 1208   zpU7rEseBMH8         100.00                  14.0             3.0
# 1209   zpr8w4jCfVPe         100.00                  14.0             3.0
# 1210   zwBG0rZ05Mcb          46.67                  13.0             3.0
# 1211   zwXD5v17Rx01          46.67                  14.0             3.0
# 1212   zwjJWCRzKhDz         100.00                  14.0             3.0
#
#       APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# 0               15.0             44.0             14.0            20.0
# 1               12.0             35.0             25.0            28.0
# 2               21.0             37.0             18.0            26.0
# 3               11.0             42.0             15.0            20.0
# 4               12.0             35.0             22.0            12.0
# ...              ...              ...              ...             ...
# 1208            11.0             41.0             16.0            23.0
# 1209             9.0             41.0             22.0            10.0
# 1210            12.0             30.0             18.0            14.0
# 1211            18.0             42.0             21.0            15.0
# 1212            14.0             36.0             18.0            13.0
#
#       APQ_P_APQ_P_PP  SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Difficulties_Total  \
# 0               27.0                       3.0                        17.0
# 1               30.0                       5.0                        20.0
# 2               28.0                       3.0                        24.0
# 3               28.0                       0.0                         5.0
# 4               24.0                       6.0                        23.0
# ...              ...                       ...                         ...
# 1208            24.0                       0.0                         8.0
# 1209            29.0                       1.0                        15.0
# 1210            24.0                       0.0                        10.0
# 1211            25.0                       2.0                         5.0
# 1212            22.0                       5.0                        20.0
#
#       SDQ_SDQ_Emotional_Problems  SDQ_SDQ_Externalizing  \
# 0                            4.0                   11.0
# 1                            4.0                   13.0
# 2                            7.0                   10.0
# 3                            0.0                    3.0
# 4                            7.0                   15.0
# ...                          ...                    ...
# 1208                         0.0                    6.0
# 1209                         3.0                    8.0
# 1210                         3.0                    5.0
# 1211                         0.0                    5.0
# 1212                         5.0                   13.0
#
#       SDQ_SDQ_Generating_Impact  SDQ_SDQ_Hyperactivity  SDQ_SDQ_Internalizing  \
# 0                           5.0                    8.0                    6.0
# 1                           5.0                    8.0                    7.0
# 2                          10.0                    7.0                   14.0
# 3                           0.0                    3.0                    2.0
# 4                           8.0                    9.0                    8.0
# ...                         ...                    ...                    ...
# 1208                        6.0                    6.0                    2.0
# 1209                        3.0                    7.0                    7.0
# 1210                        3.0                    5.0                    5.0
# 1211                        0.0                    3.0                    0.0
# 1212                        5.0                    8.0                    7.0
#
#       SDQ_SDQ_Peer_Problems  SDQ_SDQ_Prosocial  MRI_Track_Age_at_Scan
# 0                       2.0                9.0              14.274127
# 1                       3.0                8.0                    NaN
# 2                       7.0                7.0              13.463381
# 3                       2.0                6.0               9.572553
# 4                       1.0                4.0               6.654574
# ...                     ...                ...                    ...
# 1208                    2.0                8.0              12.669860
# 1209                    4.0                7.0                    NaN
# 1210                    2.0                8.0               8.155258
# 1211                    0.0                7.0               7.364020
# 1212                    2.0                8.0              11.272986
#
# [1213 rows x 19 columns]

# %%
numeric_df = TRAIN_QUANTITATIVE.select_dtypes(include=['float64', 'int64'])
numeric_df_imputed = TRAIN_QUANTITATIVE_imputed.select_dtypes(include=['float64', 'int64'])

num_columns = len(numeric_df.columns)  
fig, axes = plt.subplots(num_columns, 2, figsize=(12, num_columns * 4))  # 2 subplots (distribution and boxplot) for each column

for i, column in enumerate(numeric_df.columns):
    # Distribution Plot before
    sns.histplot(numeric_df[column], ax=axes[i, 0], kde=True)  # kde=True adds a kernel density estimate (smoothed curve)
    axes[i, 0].set_title(f'Distribution of {column} before')

    # Distribution Plot After
    sns.histplot(numeric_df_imputed[column], ax=axes[i, 1], kde=True)  # kde=True adds a kernel density estimate (smoothed curve)
    axes[i, 1].set_title(f'Distribution of {column} After')

# Adjust layout to avoid overlap
plt.tight_layout()
plt.show()

# %%
get_messing(TRAIN_QUANTITATIVE_imputed)
# Out:
# No Messing Data

# %% [markdown]
# ### TRAIN_CATEGORICAL

# %%
get_messing(TRAIN_CATEGORICAL)
# Out:
#                                   Count      %
# participant_id                        0   0.00
# Basic_Demos_Enroll_Year               0   0.00
# Basic_Demos_Study_Site                0   0.00
# PreInt_Demos_Fam_Child_Ethnicity     43   3.54
# PreInt_Demos_Fam_Child_Race          54   4.45
# MRI_Track_Scan_Location               3   0.25
# Barratt_Barratt_P1_Edu               15   1.24
# Barratt_Barratt_P1_Occ               31   2.56
# Barratt_Barratt_P2_Edu              198  16.32
# Barratt_Barratt_P2_Occ              222  18.30

# %%
TRAIN_CATEGORICAL.head()
# Out:
#   participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 0   00aIpNTbG5uh                     2019                       4
# 1   00fV0OyyoLfw                     2017                       1
# 2   04X1eiS79T4B                     2017                       1
# 3   05ocQutkURd6                     2018                       1
# 4   06YUNBA9ZRLq                     2018                       1
#
#    PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 0                               1.0                          0.0
# 1                               0.0                          9.0
# 2                               1.0                          2.0
# 3                               3.0                          8.0
# 4                               0.0                          1.0
#
#    MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  Barratt_Barratt_P1_Occ  \
# 0                      3.0                    21.0                    45.0
# 1                      2.0                    21.0                     0.0
# 2                      2.0                     9.0                     0.0
# 3                      2.0                    18.0                    10.0
# 4                      2.0                    12.0                     0.0
#
#    Barratt_Barratt_P2_Edu  Barratt_Barratt_P2_Occ
# 0                     NaN                     NaN
# 1                    21.0                    45.0
# 2                     NaN                     NaN
# 3                    18.0                     0.0
# 4                     NaN                     NaN

# %%
TRAIN_CATEGORICAL[['Basic_Demos_Study_Site','MRI_Track_Scan_Location']]
# Out:
#       Basic_Demos_Study_Site  MRI_Track_Scan_Location
# 0                          4                      3.0
# 1                          1                      2.0
# 2                          1                      2.0
# 3                          1                      2.0
# 4                          1                      2.0
# ...                      ...                      ...
# 1208                       1                      2.0
# 1209                       3                      3.0
# 1210                       1                      2.0
# 1211                       1                      3.0
# 1212                       4                      3.0
#
# [1213 rows x 2 columns]

# %% [raw]
# # Get the counts of each combination of the two columns
# cross_tab = pd.crosstab(TRAIN_CATEGORICAL['Basic_Demos_Study_Site'], TRAIN_CATEGORICAL['MRI_Track_Scan_Location'])
#
# # Plot as stacked bar chart
# cross_tab.plot(kind='bar', stacked=True, figsize=(10, 6))
#
# plt.title('Comparison of Study Site and Scan Location')
# plt.xlabel('Study Site')
# plt.ylabel('Count')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %%
TRAIN_CATEGORICAL[TRAIN_CATEGORICAL['MRI_Track_Scan_Location'].isna()]
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 585    UmN79UUheNpw                     2016                       1
# 1155   x0yuhCZiG4mU                     2016                       1
# 1201   zSOTbT8r7FQ2                     2016                       1
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 585                                0.0                          0.0
# 1155                               0.0                          0.0
# 1201                               0.0                          NaN
#
#       MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  Barratt_Barratt_P1_Occ  \
# 585                       NaN                    21.0                    25.0
# 1155                      NaN                    18.0                    40.0
# 1201                      NaN                    15.0                     0.0
#
#       Barratt_Barratt_P2_Edu  Barratt_Barratt_P2_Occ
# 585                     18.0                    45.0
# 1155                    18.0                    45.0
# 1201                    21.0                    35.0

# %%
TRAIN_CATEGORICAL_imputed = TRAIN_CATEGORICAL.copy()
TRAIN_CATEGORICAL_imputed['MRI_Track_Scan_Location'] = TRAIN_CATEGORICAL.groupby(['Basic_Demos_Enroll_Year', 'Basic_Demos_Study_Site'])['MRI_Track_Scan_Location']\
        .transform(lambda x: x.fillna(x.mode()[0]))  
TRAIN_CATEGORICAL_imputed.iloc[[585, 1155, 1201]]
# Out:
#      participant_id  Basic_Demos_Enroll_Year  Basic_Demos_Study_Site  \
# 585    UmN79UUheNpw                     2016                       1
# 1155   x0yuhCZiG4mU                     2016                       1
# 1201   zSOTbT8r7FQ2                     2016                       1
#
#       PreInt_Demos_Fam_Child_Ethnicity  PreInt_Demos_Fam_Child_Race  \
# 585                                0.0                          0.0
# 1155                               0.0                          0.0
# 1201                               0.0                          NaN
#
#       MRI_Track_Scan_Location  Barratt_Barratt_P1_Edu  Barratt_Barratt_P1_Occ  \
# 585                       1.0                    21.0                    25.0
# 1155                      1.0                    18.0                    40.0
# 1201                      1.0                    15.0                     0.0
#
#       Barratt_Barratt_P2_Edu  Barratt_Barratt_P2_Occ
# 585                     18.0                    45.0
# 1155                    18.0                    45.0
# 1201                    21.0                    35.0

# %%
get_messing(TRAIN_CATEGORICAL_imputed)
# Out:
#                                   Count      %
# participant_id                        0   0.00
# Basic_Demos_Enroll_Year               0   0.00
# Basic_Demos_Study_Site                0   0.00
# PreInt_Demos_Fam_Child_Ethnicity     43   3.54
# PreInt_Demos_Fam_Child_Race          54   4.45
# MRI_Track_Scan_Location               0   0.00
# Barratt_Barratt_P1_Edu               15   1.24
# Barratt_Barratt_P1_Occ               31   2.56
# Barratt_Barratt_P2_Edu              198  16.32
# Barratt_Barratt_P2_Occ              222  18.30

# %% [raw]
# TRAIN_CATEGORICAL_imputed.groupby(
#     ['Basic_Demos_Enroll_Year', 'Basic_Demos_Study_Site']
# )['PreInt_Demos_Fam_Child_Race'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
col_to_impute = ['Barratt_Barratt_P1_Occ','Barratt_Barratt_P2_Edu','Barratt_Barratt_P2_Occ']
for col in col_to_impute:
    TRAIN_CATEGORICAL_imputed[col] = TRAIN_CATEGORICAL_imputed.groupby(
        ['Basic_Demos_Study_Site','Barratt_Barratt_P1_Edu']
    )[col].transform(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)
get_messing(TRAIN_CATEGORICAL_imputed,drop=True)
# Out:
#                                   Count     %
# PreInt_Demos_Fam_Child_Ethnicity   43.0  3.54
# PreInt_Demos_Fam_Child_Race        54.0  4.45
# Barratt_Barratt_P1_Edu             15.0  1.24
# Barratt_Barratt_P1_Occ             15.0  1.24
# Barratt_Barratt_P2_Edu             19.0  1.57
# Barratt_Barratt_P2_Occ             19.0  1.57

# %%
from sklearn.impute import SimpleImputer
cols = get_messing(TRAIN_CATEGORICAL_imputed,drop=True).index.tolist()
imputer = SimpleImputer(strategy='most_frequent')
TRAIN_CATEGORICAL_imputed[cols] = imputer.fit_transform(TRAIN_CATEGORICAL_imputed[cols])
get_messing(TRAIN_CATEGORICAL_imputed,drop=True)
# Out:
# No Messing Data

# %%
numeric_df = TRAIN_CATEGORICAL.select_dtypes(include=['float64', 'int64'])
numeric_df_imputed = TRAIN_CATEGORICAL_imputed.select_dtypes(include=['float64', 'int64'])

num_columns = len(numeric_df.columns)  
fig, axes = plt.subplots(num_columns, 2, figsize=(12, num_columns * 4))  # 2 subplots (distribution and boxplot) for each column

for i, column in enumerate(numeric_df.columns):
    # Distribution Plot before
    sns.histplot(numeric_df[column], ax=axes[i, 0], kde=True)  # kde=True adds a kernel density estimate (smoothed curve)
    axes[i, 0].set_title(f'Distribution of {column} before')

    # Distribution Plot After
    sns.histplot(numeric_df_imputed[column], ax=axes[i, 1], kde=True)  # kde=True adds a kernel density estimate (smoothed curve)
    axes[i, 1].set_title(f'Distribution of {column} After')

# Adjust layout to avoid overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Outliers

# %%
numeric_df=TRAIN_QUANTITATIVE_imputed.select_dtypes(include=['float64', 'int64'])
Outliers=numeric_df.columns.tolist()
print(len(Outliers))
Outliers
# Out:
# 18
# ['EHQ_EHQ_Total',
#  'ColorVision_CV_Score',
#  'APQ_P_APQ_P_CP',
#  'APQ_P_APQ_P_ID',
#  'APQ_P_APQ_P_INV',
#  'APQ_P_APQ_P_OPD',
#  'APQ_P_APQ_P_PM',
#  'APQ_P_APQ_P_PP',
#  'SDQ_SDQ_Conduct_Problems',
#  'SDQ_SDQ_Difficulties_Total',
#  'SDQ_SDQ_Emotional_Problems',
#  'SDQ_SDQ_Externalizing',
#  'SDQ_SDQ_Generating_Impact',
#  'SDQ_SDQ_Hyperactivity',
#  'SDQ_SDQ_Internalizing',
#  'SDQ_SDQ_Peer_Problems',
#  'SDQ_SDQ_Prosocial',
#  'MRI_Track_Age_at_Scan']

# %%
df = handel_Outliers(numeric_df,Outliers,handel=True)
# Out:
# EHQ_EHQ_Total  :
#
# IQR = 46.730000000000004
# lower,upper bounds [-23.424999999999997,163.495]
# Total number of outliers in EHQ_EHQ_Total are 110
# ===========================================
# ColorVision_CV_Score  :
#
# IQR = 0.0
# lower,upper bounds [14.0,14.0]
# Total number of outliers in ColorVision_CV_Score are 234
# ===========================================
# APQ_P_APQ_P_CP  :
#
# IQR = 1.0
# lower,upper bounds [1.5,5.5]
# Total number of outliers in APQ_P_APQ_P_CP are 128
# ===========================================
# APQ_P_APQ_P_ID  :
#
# IQR = 5.0
# lower,upper bounds [3.5,23.5]
# Total number of outliers in APQ_P_APQ_P_ID are 3
# ===========================================
# APQ_P_APQ_P_INV  :
#
# IQR = 7.0
# lower,upper bounds [25.5,53.5]
# Total number of outliers in APQ_P_APQ_P_INV are 3
# ===========================================
# APQ_P_APQ_P_OPD  :
#
# IQR = 4.0
# lower,upper bounds [10.0,26.0]
# Total number of outliers in APQ_P_APQ_P_OPD are 13
# ===========================================
# APQ_P_APQ_P_PM  :
#
# IQR = 6.0
# lower,upper bounds [4.0,28.0]
# Total number of outliers in APQ_P_APQ_P_PM are 37
# ===========================================
# APQ_P_APQ_P_PP  :
#
# IQR = 5.0
# lower,upper bounds [15.5,35.5]
# Total number of outliers in APQ_P_APQ_P_PP are 2
# ===========================================
# SDQ_SDQ_Conduct_Problems  :
#
# IQR = 3.0
# lower,upper bounds [-4.5,7.5]
# Total number of outliers in SDQ_SDQ_Conduct_Problems are 17
# ===========================================
# SDQ_SDQ_Difficulties_Total  :
#
# IQR = 10.0
# lower,upper bounds [-8.0,32.0]
# Total number of outliers in SDQ_SDQ_Difficulties_Total are 1
# ===========================================
# SDQ_SDQ_Emotional_Problems  :
#
# IQR = 3.0
# lower,upper bounds [-3.5,8.5]
# Total number of outliers in SDQ_SDQ_Emotional_Problems are 11
# ===========================================
# SDQ_SDQ_Externalizing  :
#
# IQR = 5.0
# lower,upper bounds [-2.5,17.5]
# Total number of outliers in SDQ_SDQ_Externalizing are 7
# ===========================================
# SDQ_SDQ_Generating_Impact  :
#
# IQR = 4.0
# lower,upper bounds [-4.0,12.0]
# Total number of outliers in SDQ_SDQ_Generating_Impact are 0
# ===========================================
# SDQ_SDQ_Hyperactivity  :
#
# IQR = 4.0
# lower,upper bounds [-2.0,14.0]
# Total number of outliers in SDQ_SDQ_Hyperactivity are 0
# ===========================================
# SDQ_SDQ_Internalizing  :
#
# IQR = 5.0
# lower,upper bounds [-5.5,14.5]
# Total number of outliers in SDQ_SDQ_Internalizing are 10
# ===========================================
# SDQ_SDQ_Peer_Problems  :
#
# IQR = 4.0
# lower,upper bounds [-6.0,10.0]
# Total number of outliers in SDQ_SDQ_Peer_Problems are 0
# ===========================================
# SDQ_SDQ_Prosocial  :
#
# IQR = 4.0
# lower,upper bounds [0.0,16.0]
# Total number of outliers in SDQ_SDQ_Prosocial are 0
# ===========================================
# MRI_Track_Age_at_Scan  :
#
# IQR = 3.699064
# lower,upper bounds [3.512435,18.308691]
# Total number of outliers in MRI_Track_Age_at_Scan are 17
# ===========================================
# All ouliers Handeled successfully

# %%
df_old = TRAIN_QUANTITATIVE_imputed.copy()
num_columns = len(Outliers)  # Number of columns in your DataFrame
fig, axes = plt.subplots(num_columns, 2, figsize=(12, num_columns * 4))  # 2 subplots (distribution and boxplot) for each column

# Loop through each column to create distribution and boxplot
for i, column in enumerate(Outliers):
    # Before
    sns.boxplot(x=df_old[column], ax=axes[i, 0])  # kde=True adds a kernel density estimate (smoothed curve)
    axes[i, 0].set_title(f'Box Plot of  {column} (Before)')

    # After
    sns.boxplot(x=df[column], ax=axes[i, 1])
    axes[i, 1].set_title(f'Box Plot of {column} (After)')

# Adjust layout to avoid overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Reduction

# %% [markdown]
# ### TRAIN_FUNCTIONAL_CONNECTOME_MATRICES

# %%
df = TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.iloc[:,1:]
df
# Out:
#       0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  0throw_4thcolumn  \
# 0             0.361339          0.791402          0.530706          0.623133
# 1             0.051430          0.613198          0.635255          0.391237
# 2            -0.305747          0.750316         -0.005342          0.458421
# 3             0.450442          0.731530          0.799147          0.701688
# 4             0.415220          0.585700          0.355835          0.664142
# ...                ...               ...               ...               ...
# 1208         -0.017270          0.856987          0.827741          0.548133
# 1209          0.342895          0.653258          0.691103          0.271458
# 1210          0.251472          0.692684          0.544077          0.622913
# 1211         -0.045660          0.207386         -0.140892          0.053852
# 1212          0.068941          0.447167          0.418621          0.371057
#
#       0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  0throw_8thcolumn  \
# 0             0.845830          0.680234          0.537144          0.387455
# 1             0.451225          0.600475          0.420935          0.234825
# 2             0.757530          0.756288          0.799046          0.622567
# 3             0.747468          0.523304          0.575033          0.187189
# 4             0.683491          0.380201          0.375091          0.212314
# ...                ...               ...               ...               ...
# 1208          0.800407          0.574002          0.798349          0.284567
# 1209          0.593868          0.516559          0.360994          0.140348
# 1210          0.658320          0.481675          0.476222          0.293739
# 1211          0.204124          0.479489          0.333045          0.239930
# 1212          0.426226          0.613174          0.284948          0.184231
#
#       0throw_9thcolumn  0throw_10thcolumn  ...  195throw_196thcolumn  \
# 0             0.498571           0.049068  ...             -0.047477
# 1             0.322048           0.181864  ...             -0.143218
# 2             0.659165           0.519783  ...             -0.133778
# 3             0.441150          -0.004607  ...             -0.096647
# 4             0.445294           0.226854  ...             -0.158995
# ...                ...                ...  ...                   ...
# 1208          0.155855           0.435824  ...              0.156577
# 1209          0.062568          -0.025561  ...             -0.039988
# 1210          0.368002           0.236086  ...             -0.126600
# 1211          0.314171           0.219034  ...              0.343204
# 1212          0.283633           0.039043  ...              0.157897
#
#       195throw_197thcolumn  195throw_198thcolumn  195throw_199thcolumn  \
# 0                -0.096450             -0.280312              0.037560
# 1                -0.276464             -0.332783             -0.332711
# 2                -0.108588             -0.002132             -0.175586
# 3                -0.041420             -0.199576             -0.216457
# 4                -0.274017             -0.141012             -0.002865
# ...                    ...                   ...                   ...
# 1208             -0.233931             -0.140041             -0.183657
# 1209             -0.087121             -0.049484             -0.119850
# 1210             -0.393645             -0.074682             -0.204213
# 1211              0.198827              0.253990              0.198741
# 1212              0.122978              0.112789              0.211312
#
#       196throw_197thcolumn  196throw_198thcolumn  196throw_199thcolumn  \
# 0                 0.423037              0.242453              0.336213
# 1                 0.556939              0.475578              0.429196
# 2                 0.679183              0.290292              0.486680
# 3                 0.519074              0.298586              0.415466
# 4                 0.515169              0.336139              0.316430
# ...                    ...                   ...                   ...
# 1208              0.253419              0.520024              0.337320
# 1209              0.610159              0.570343              0.303530
# 1210              0.370247              0.238742              0.131456
# 1211              0.648260              0.055241              0.491985
# 1212              0.601190              0.587116              0.312695
#
#       197throw_198thcolumn  197throw_199thcolumn  198throw_199thcolumn
# 0                 0.402338              0.327915              0.539032
# 1                 0.457970              0.312571              0.595978
# 2                 0.255208              0.575017              0.605182
# 3                 0.511607              0.361204              0.446613
# 4                 0.442230              0.177079              0.378278
# ...                    ...                   ...                   ...
# 1208              0.629728              0.678281              0.814656
# 1209              0.850718              0.725138              0.721350
# 1210              0.472743              0.588147              0.418452
# 1211              0.118676              0.404331              0.537121
# 1212              0.485938              0.189102              0.354333
#
# [1213 rows x 19900 columns]

# %% [markdown]
# **What is "Explained Variance" in PCA?**\
# When you apply PCA, you're transforming your original data (maybe hundreds or thousands of features) into a new set of principal components (PCs).\
# Each PC captures a portion of the total variance (i.e. the "spread" or information) in the data.
#
# - Explained Variance = How much variation in the data is captured by a single principal component.
#
# - Cumulative Explained Variance = The total variance captured up to that component (e.g. PC1 + PC2 + PC3...).

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

pca = PCA().fit(df)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.show()

# %%
pca = PCA(n_components=0.7)  # Keep 75% of the variance
reduced_data = pca.fit_transform(TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.iloc[:,1:])
reduced_data.shape
# Out:
# (1213, 292)

# %%
pca_columns = [f'PC_{i+1}' for i in range(reduced_data.shape[1])]

# Convert to DataFrame
reduced_df = pd.DataFrame(reduced_data, columns=pca_columns)
reduced_df['participant_id'] = TRAIN_FUNCTIONAL_CONNECTOME_MATRICES['participant_id']
reduced_df
# Out:
#           PC_1      PC_2      PC_3      PC_4      PC_5      PC_6      PC_7  \
# 0    -5.367968 -5.068500  1.508765  2.062678  0.697009 -0.371967 -2.574856
# 1    -4.108815 -3.920926  0.070828  1.683232 -1.204590  1.199795 -0.275150
# 2    -5.987513 -5.386339  2.510001 -3.763229  1.955189 -1.496322 -2.904989
# 3    -3.775851 -6.756400  0.928621  3.646527 -3.212114 -0.677817 -2.633906
# 4     1.979975 -4.088958 -3.459130  3.523769 -0.906082 -0.608358 -5.656954
# ...        ...       ...       ...       ...       ...       ...       ...
# 1208 -6.437288 -6.021686  3.898046  1.085205  2.015552 -1.540975  1.796908
# 1209  7.206823 -3.618114  6.848007  0.609650  0.508437 -1.183881  6.298111
# 1210  0.840310 -4.220060 -0.619828  0.337278  2.806762  0.060692  2.065328
# 1211  9.373537  4.577333  1.337234 -5.033227  1.456240 -1.564184  1.469079
# 1212 -4.129379  8.643124  1.025399 -3.024945  0.328388  0.856948 -5.190872
#
#           PC_8      PC_9     PC_10  ...    PC_700    PC_701    PC_702  \
# 0    -1.824426 -2.881217  2.042189  ... -0.489485 -0.885926 -0.139877
# 1     0.007479  0.797247 -1.207645  ... -0.662983  0.497977  0.005155
# 2     2.163707  3.292545 -0.556093  ...  0.107149  0.757717  0.999471
# 3    -0.383115 -0.332242  2.460489  ...  0.637467  0.054950 -0.145480
# 4     3.202955  2.225541  1.825331  ... -0.986809  0.547674 -0.269254
# ...        ...       ...       ...  ...       ...       ...       ...
# 1208 -1.266181 -2.146448 -0.011019  ... -0.229335 -0.249406  0.073153
# 1209 -1.214415  3.531693 -3.756891  ...  0.052502  0.190441  0.378359
# 1210  0.877024 -1.137559 -0.081301  ...  0.964064  0.113720  0.272256
# 1211 -0.607567 -2.958979 -2.511220  ... -0.826670 -0.314266 -0.002824
# 1212 -2.671200 -2.472105 -0.851663  ... -0.628812  0.512541 -0.433779
#
#         PC_703    PC_704    PC_705    PC_706    PC_707    PC_708  \
# 0    -0.838073  0.221972  0.063530 -0.186907  0.787447 -0.134540
# 1    -0.245164 -0.469853 -0.304255 -1.391458  0.073335  0.337728
# 2    -0.093451  0.526037 -0.017413 -0.008086  0.640064  0.037636
# 3    -0.153771  0.006845  0.356799  1.287903 -0.416973  0.363878
# 4     0.718975  0.132122 -0.394970  0.328607  0.172136 -0.324686
# ...        ...       ...       ...       ...       ...       ...
# 1208 -0.264653  0.586030 -0.051457  0.243260  0.742532  0.430341
# 1209  0.418191  0.283857 -0.647356 -0.628950  0.387956 -0.037862
# 1210 -0.099461  0.332594  0.362978 -0.235831 -0.475076 -0.122371
# 1211  0.008047 -0.121917  0.327537  0.127917 -0.221051  0.306661
# 1212  0.534382  0.332080  0.813323 -0.451222 -0.319734 -0.641685
#
#       participant_id
# 0       00aIpNTbG5uh
# 1       00fV0OyyoLfw
# 2       04X1eiS79T4B
# 3       05ocQutkURd6
# 4       06YUNBA9ZRLq
# ...              ...
# 1208    zpU7rEseBMH8
# 1209    zpr8w4jCfVPe
# 1210    zwBG0rZ05Mcb
# 1211    zwXD5v17Rx01
# 1212    zwjJWCRzKhDz
#
# [1213 rows x 709 columns]

# %% [markdown]
# ## Merging

# %%
merged_df = pd.merge(TRAIN_QUANTITATIVE_imputed, TRAIN_CATEGORICAL_imputed, on='participant_id', how='inner')
tmp = pd.merge(merged_df, reduced_df, on='participant_id', how='inner')
data = pd.merge(tmp, TRAINING_SOLUTIONS, on='participant_id', how='inner')

# %%
data.head()
# Out:
#   participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0   00aIpNTbG5uh         100.00                  13.0             3.0
# 1   00fV0OyyoLfw          92.27                  14.0             3.0
# 2   04X1eiS79T4B          86.67                  14.0             3.0
# 3   05ocQutkURd6          93.34                  14.0             3.0
# 4   06YUNBA9ZRLq           0.00                  14.0             8.0
#
#    APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# 0            15.0             44.0             14.0            20.0
# 1            12.0             35.0             25.0            28.0
# 2            21.0             37.0             18.0            26.0
# 3            11.0             42.0             15.0            20.0
# 4            12.0             35.0             22.0            12.0
#
#    APQ_P_APQ_P_PP  SDQ_SDQ_Conduct_Problems  ...    PC_701    PC_702  \
# 0            27.0                       3.0  ... -0.885926 -0.139877
# 1            30.0                       5.0  ...  0.497977  0.005155
# 2            28.0                       3.0  ...  0.757717  0.999471
# 3            28.0                       0.0  ...  0.054950 -0.145480
# 4            24.0                       6.0  ...  0.547674 -0.269254
#
#      PC_703    PC_704    PC_705    PC_706    PC_707    PC_708  ADHD_Outcome  \
# 0 -0.838073  0.221972  0.063530 -0.186907  0.787447 -0.134540             1
# 1 -0.245164 -0.469853 -0.304255 -1.391458  0.073335  0.337728             1
# 2 -0.093451  0.526037 -0.017413 -0.008086  0.640064  0.037636             0
# 3 -0.153771  0.006845  0.356799  1.287903 -0.416973  0.363878             0
# 4  0.718975  0.132122 -0.394970  0.328607  0.172136 -0.324686             1
#
#    Sex_F
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
#
# [5 rows x 738 columns]

# %% [markdown]
# ## Re-indexing

# %%
data = data.set_index('participant_id').sort_index()
data.head()
# Out:
#                 EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# participant_id
# 00aIpNTbG5uh           100.00                  13.0             3.0
# 00fV0OyyoLfw            92.27                  14.0             3.0
# 04X1eiS79T4B            86.67                  14.0             3.0
# 05ocQutkURd6            93.34                  14.0             3.0
# 06YUNBA9ZRLq             0.00                  14.0             8.0
#
#                 APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  \
# participant_id
# 00aIpNTbG5uh              15.0             44.0             14.0
# 00fV0OyyoLfw              12.0             35.0             25.0
# 04X1eiS79T4B              21.0             37.0             18.0
# 05ocQutkURd6              11.0             42.0             15.0
# 06YUNBA9ZRLq              12.0             35.0             22.0
#
#                 APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  SDQ_SDQ_Conduct_Problems  \
# participant_id
# 00aIpNTbG5uh              20.0            27.0                       3.0
# 00fV0OyyoLfw              28.0            30.0                       5.0
# 04X1eiS79T4B              26.0            28.0                       3.0
# 05ocQutkURd6              20.0            28.0                       0.0
# 06YUNBA9ZRLq              12.0            24.0                       6.0
#
#                 SDQ_SDQ_Difficulties_Total  ...    PC_701    PC_702    PC_703  \
# participant_id                              ...
# 00aIpNTbG5uh                          17.0  ... -0.885926 -0.139877 -0.838073
# 00fV0OyyoLfw                          20.0  ...  0.497977  0.005155 -0.245164
# 04X1eiS79T4B                          24.0  ...  0.757717  0.999471 -0.093451
# 05ocQutkURd6                           5.0  ...  0.054950 -0.145480 -0.153771
# 06YUNBA9ZRLq                          23.0  ...  0.547674 -0.269254  0.718975
#
#                   PC_704    PC_705    PC_706    PC_707    PC_708  \
# participant_id
# 00aIpNTbG5uh    0.221972  0.063530 -0.186907  0.787447 -0.134540
# 00fV0OyyoLfw   -0.469853 -0.304255 -1.391458  0.073335  0.337728
# 04X1eiS79T4B    0.526037 -0.017413 -0.008086  0.640064  0.037636
# 05ocQutkURd6    0.006845  0.356799  1.287903 -0.416973  0.363878
# 06YUNBA9ZRLq    0.132122 -0.394970  0.328607  0.172136 -0.324686
#
#                 ADHD_Outcome  Sex_F
# participant_id
# 00aIpNTbG5uh               1      0
# 00fV0OyyoLfw               1      0
# 04X1eiS79T4B               0      1
# 05ocQutkURd6               0      1
# 06YUNBA9ZRLq               1      0
#
# [5 rows x 737 columns]

# %%
X = data.iloc[:,:-2]
X.head()
# Out:
#                 EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# participant_id
# 00aIpNTbG5uh           100.00                  13.0             3.0
# 00fV0OyyoLfw            92.27                  14.0             3.0
# 04X1eiS79T4B            86.67                  14.0             3.0
# 05ocQutkURd6            93.34                  14.0             3.0
# 06YUNBA9ZRLq             0.00                  14.0             8.0
#
#                 APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  \
# participant_id
# 00aIpNTbG5uh              15.0             44.0             14.0
# 00fV0OyyoLfw              12.0             35.0             25.0
# 04X1eiS79T4B              21.0             37.0             18.0
# 05ocQutkURd6              11.0             42.0             15.0
# 06YUNBA9ZRLq              12.0             35.0             22.0
#
#                 APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  SDQ_SDQ_Conduct_Problems  \
# participant_id
# 00aIpNTbG5uh              20.0            27.0                       3.0
# 00fV0OyyoLfw              28.0            30.0                       5.0
# 04X1eiS79T4B              26.0            28.0                       3.0
# 05ocQutkURd6              20.0            28.0                       0.0
# 06YUNBA9ZRLq              12.0            24.0                       6.0
#
#                 SDQ_SDQ_Difficulties_Total  ...    PC_699    PC_700    PC_701  \
# participant_id                              ...
# 00aIpNTbG5uh                          17.0  ... -0.404643 -0.489485 -0.885926
# 00fV0OyyoLfw                          20.0  ... -1.034934 -0.662983  0.497977
# 04X1eiS79T4B                          24.0  ...  0.382100  0.107149  0.757717
# 05ocQutkURd6                           5.0  ... -0.087300  0.637467  0.054950
# 06YUNBA9ZRLq                          23.0  ... -0.439174 -0.986809  0.547674
#
#                   PC_702    PC_703    PC_704    PC_705    PC_706    PC_707  \
# participant_id
# 00aIpNTbG5uh   -0.139877 -0.838073  0.221972  0.063530 -0.186907  0.787447
# 00fV0OyyoLfw    0.005155 -0.245164 -0.469853 -0.304255 -1.391458  0.073335
# 04X1eiS79T4B    0.999471 -0.093451  0.526037 -0.017413 -0.008086  0.640064
# 05ocQutkURd6   -0.145480 -0.153771  0.006845  0.356799  1.287903 -0.416973
# 06YUNBA9ZRLq   -0.269254  0.718975  0.132122 -0.394970  0.328607  0.172136
#
#                   PC_708
# participant_id
# 00aIpNTbG5uh   -0.134540
# 00fV0OyyoLfw    0.337728
# 04X1eiS79T4B    0.037636
# 05ocQutkURd6    0.363878
# 06YUNBA9ZRLq   -0.324686
#
# [5 rows x 735 columns]

# %%
y = data.iloc[:,-2:]
y.head()
# Out:
#                 ADHD_Outcome  Sex_F
# participant_id
# 00aIpNTbG5uh               1      0
# 00fV0OyyoLfw               1      0
# 04X1eiS79T4B               0      1
# 05ocQutkURd6               0      1
# 06YUNBA9ZRLq               1      0

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Variance Threshold

# %%
X.var().describe()
# Out:
# count     735.000000
# mean        5.203919
# std        91.654830
# min         0.217468
# 25%         0.310528
# 50%         0.473468
# 75%         0.880622
# max      2453.546823
# dtype: float64

# %%
threshold = 0.1

# %%
variances = X.var()
variances.sort_values(ascending=True)
# Out:
# PC_708                           0.217468
# PC_707                           0.217931
# PC_706                           0.218241
# PC_705                           0.218661
# PC_704                           0.218951
#                                  ...
# PC_1                            35.770049
# SDQ_SDQ_Difficulties_Total      42.199535
# Barratt_Barratt_P2_Occ         100.852291
# Barratt_Barratt_P1_Occ         384.670946
# EHQ_EHQ_Total                 2453.546823
# Length: 735, dtype: float64

# %%
variance_series = pd.Series(variances, index=X.columns)
low_variance_cols = variance_series[variance_series < threshold].index.tolist()

print("Low variance columns:", len(low_variance_cols))
# Out:
# Low variance columns: 0

# %% [markdown]
# ### Univariate Feature Selection

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif

# 1. Select features for ADHD
selector_adhd = SelectKBest(score_func=mutual_info_classif, k=350)
selector_adhd.fit(X, y.iloc[:, 0])
features_adhd = X.columns[selector_adhd.get_support()]
scores_adhd = selector_adhd.scores_[selector_adhd.get_support()]
adhd_df = pd.DataFrame({'Feature': features_adhd, 'Score_ADHD': scores_adhd})

# 2. Select features for Sex
selector_sex = SelectKBest(score_func=mutual_info_classif, k=350)
selector_sex.fit(X, y.iloc[:, 1])
features_sex = X.columns[selector_sex.get_support()]
scores_sex = selector_sex.scores_[selector_sex.get_support()]
sex_df = pd.DataFrame({'Feature': features_sex, 'Score_Sex': scores_sex})

# %%
# 3. Find common features
common_features = set(features_adhd).intersection(set(features_sex))

# 4. Merge to show scores (variation 2)
common_df = pd.merge(adhd_df, sex_df, on='Feature')
print("Common Selected Features with Scores:")
print(common_df.sort_values(by=['Score_ADHD', 'Score_Sex'], ascending=False))

# 5. Show only feature names (variation 1)
print("\n Common Selected Feature Names:")
print(list(common_df['Feature']))
print(common_df.shape)
# Out:
# Common Selected Features with Scores:
#                         Feature  Score_ADHD  Score_Sex
# 4         SDQ_SDQ_Hyperactivity    0.171587   0.010197
# 2         SDQ_SDQ_Externalizing    0.156755   0.008110
# 1    SDQ_SDQ_Difficulties_Total    0.120495   0.009365
# 3     SDQ_SDQ_Generating_Impact    0.108646   0.016213
# 0      SDQ_SDQ_Conduct_Problems    0.063773   0.014881
# ..                          ...         ...        ...
# 33                       PC_120    0.001370   0.012900
# 146                      PC_597    0.001293   0.023504
# 52                       PC_185    0.001222   0.010921
# 143                      PC_588    0.001212   0.008690
# 12                        PC_15    0.001181   0.008743
#
# [171 rows x 3 columns]
#
#  Common Selected Feature Names:
# ['SDQ_SDQ_Conduct_Problems', 'SDQ_SDQ_Difficulties_Total', 'SDQ_SDQ_Externalizing', 'SDQ_SDQ_Generating_Impact', 'SDQ_SDQ_Hyperactivity', 'SDQ_SDQ_Internalizing', 'SDQ_SDQ_Peer_Problems', 'SDQ_SDQ_Prosocial', 'Basic_Demos_Study_Site', 'MRI_Track_Scan_Location', 'PC_8', 'PC_9', 'PC_15', 'PC_22', 'PC_28', 'PC_32', 'PC_33', 'PC_35', 'PC_36', 'PC_43', 'PC_44', 'PC_49', 'PC_63', 'PC_65', 'PC_75', 'PC_78', 'PC_81', 'PC_85', 'PC_89', 'PC_95', 'PC_98', 'PC_108', 'PC_109', 'PC_120', 'PC_122', 'PC_124', 'PC_125', 'PC_129', 'PC_133', 'PC_135', 'PC_141', 'PC_142', 'PC_147', 'PC_149', 'PC_156', 'PC_158', 'PC_166', 'PC_177', 'PC_178', 'PC_181', 'PC_182', 'PC_184', 'PC_185', 'PC_190', 'PC_200', 'PC_202', 'PC_206', 'PC_207', 'PC_210', 'PC_217', 'PC_226', 'PC_232', 'PC_233', 'PC_237', 'PC_239', 'PC_240', 'PC_243', 'PC_247', 'PC_249', 'PC_256', 'PC_257', 'PC_268', 'PC_270', 'PC_273', 'PC_275', 'PC_277', 'PC_285', 'PC_293', 'PC_295', 'PC_298', 'PC_299', 'PC_303', 'PC_305', 'PC_319', 'PC_329', 'PC_333', 'PC_337', 'PC_338', 'PC_349', 'PC_350', 'PC_359', 'PC_360', 'PC_391', 'PC_392', 'PC_394', 'PC_396', 'PC_398', 'PC_403', 'PC_406', 'PC_411', 'PC_412', 'PC_421', 'PC_422', 'PC_424', 'PC_429', 'PC_431', 'PC_433', 'PC_438', 'PC_443', 'PC_452', 'PC_475', 'PC_481', 'PC_485', 'PC_490', 'PC_491', 'PC_492', 'PC_493', 'PC_494', 'PC_502', 'PC_504', 'PC_506', 'PC_507', 'PC_517', 'PC_519', 'PC_523', 'PC_524', 'PC_525', 'PC_526', 'PC_548', 'PC_549', 'PC_552', 'PC_553', 'PC_557', 'PC_558', 'PC_559', 'PC_563', 'PC_564', 'PC_569', 'PC_576', 'PC_579', 'PC_581', 'PC_586', 'PC_587', 'PC_588', 'PC_592', 'PC_594', 'PC_597', 'PC_600', 'PC_604', 'PC_608', 'PC_609', 'PC_613', 'PC_617', 'PC_619', 'PC_622', 'PC_626', 'PC_633', 'PC_634', 'PC_646', 'PC_651', 'PC_664', 'PC_666', 'PC_667', 'PC_674', 'PC_679', 'PC_680', 'PC_681', 'PC_683', 'PC_699', 'PC_701', 'PC_708']
# (171, 3)

# %%
X_filtered = X[list(common_features)]
X_filtered
# Out:
#                   PC_701    PC_277    PC_569    PC_506    PC_299    PC_681  \
# participant_id
# 00aIpNTbG5uh   -0.885926 -0.516138  0.668147 -0.981937  0.401468  0.529713
# 00fV0OyyoLfw    0.497977 -1.177365 -0.371995  0.433324 -0.193369 -0.436745
# 04X1eiS79T4B    0.757717  0.312571 -0.259811 -0.057170 -1.251554 -0.606238
# 05ocQutkURd6    0.054950  0.251032  0.718920 -0.481879  0.056775 -0.261276
# 06YUNBA9ZRLq    0.547674  1.620974 -0.716660  0.323613  0.731091 -0.924931
# ...                  ...       ...       ...       ...       ...       ...
# zpU7rEseBMH8   -0.249406  0.919488  0.455074  0.256527 -0.328007  0.262779
# zpr8w4jCfVPe    0.190441 -0.080839  0.498044  0.221612 -0.547393 -1.093603
# zwBG0rZ05Mcb    0.113720 -0.340562  0.321016 -0.086916  0.017061 -0.477525
# zwXD5v17Rx01   -0.314266  0.182756 -1.173972 -0.232208 -0.272833  0.129442
# zwjJWCRzKhDz    0.512541 -0.633007 -0.500051  0.208450 -0.312964 -0.004857
#
#                    PC_95    PC_319    PC_708    PC_120  ...    PC_270  \
# participant_id                                          ...
# 00aIpNTbG5uh    0.495522  0.653002 -0.134540 -0.389222  ...  0.901018
# 00fV0OyyoLfw   -1.140333 -0.661232  0.337728 -0.388142  ... -0.483971
# 04X1eiS79T4B   -0.152809  0.499940  0.037636 -1.116080  ... -0.106919
# 05ocQutkURd6    0.277905  0.123407  0.363878 -0.965560  ...  0.257201
# 06YUNBA9ZRLq   -0.366564  0.140074 -0.324686  0.287860  ...  1.369513
# ...                  ...       ...       ...       ...  ...       ...
# zpU7rEseBMH8   -1.396686 -0.899611  0.430341  0.198835  ... -0.238826
# zpr8w4jCfVPe   -0.722429  0.049094 -0.037862  1.523251  ... -0.365491
# zwBG0rZ05Mcb   -0.861028  0.527487 -0.122371 -0.947304  ...  0.029490
# zwXD5v17Rx01    0.450748  0.445068  0.306661  0.926144  ...  1.208717
# zwjJWCRzKhDz    0.098272 -0.285723 -0.641685  0.290275  ... -0.243495
#
#                   PC_608    PC_424    PC_586  SDQ_SDQ_Difficulties_Total  \
# participant_id
# 00aIpNTbG5uh    0.752034  0.833928  0.182658                        17.0
# 00fV0OyyoLfw   -0.035371 -0.457536  0.135948                        20.0
# 04X1eiS79T4B   -0.802347  0.677101  0.602827                        24.0
# 05ocQutkURd6    0.258233 -0.304691 -0.197279                         5.0
# 06YUNBA9ZRLq    0.266904  1.193239  0.118456                        23.0
# ...                  ...       ...       ...                         ...
# zpU7rEseBMH8    0.656437 -1.356682 -0.166307                         8.0
# zpr8w4jCfVPe   -0.080516  0.485095 -0.629223                        15.0
# zwBG0rZ05Mcb    0.205248 -0.553610  0.369178                        10.0
# zwXD5v17Rx01   -0.319629 -1.741322  1.690599                         5.0
# zwjJWCRzKhDz    0.374271 -0.124781 -0.178560                        20.0
#
#                   PC_548    PC_412    PC_156  SDQ_SDQ_Generating_Impact  \
# participant_id
# 00aIpNTbG5uh   -0.213999 -0.391421  1.066416                        5.0
# 00fV0OyyoLfw    0.681074  1.422336  0.772472                        5.0
# 04X1eiS79T4B   -0.578763 -0.522436 -0.490823                       10.0
# 05ocQutkURd6    0.096809  1.033389  0.291080                        0.0
# 06YUNBA9ZRLq   -0.642111  0.123385 -1.295996                        8.0
# ...                  ...       ...       ...                        ...
# zpU7rEseBMH8   -0.740099 -1.115198  0.073811                        6.0
# zpr8w4jCfVPe   -0.174393  0.999876  0.135354                        3.0
# zwBG0rZ05Mcb    0.460728  0.193762 -1.661694                        3.0
# zwXD5v17Rx01    0.223560  0.186028  0.777863                        0.0
# zwjJWCRzKhDz   -0.671756  0.074007 -0.219653                        5.0
#
#                   PC_481
# participant_id
# 00aIpNTbG5uh   -0.115218
# 00fV0OyyoLfw    0.209462
# 04X1eiS79T4B    0.753116
# 05ocQutkURd6   -0.721753
# 06YUNBA9ZRLq    0.284133
# ...                  ...
# zpU7rEseBMH8    0.325893
# zpr8w4jCfVPe   -0.771119
# zwBG0rZ05Mcb    0.418423
# zwXD5v17Rx01    0.310540
# zwjJWCRzKhDz   -0.274793
#
# [1213 rows x 171 columns]

# %% [markdown]
# ### Recursive Feature Elimination (RFE)

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

# Initialize the model
estimator = RandomForestClassifier(n_estimators=100, random_state=42)

# 1. Fit RFE on ADHD target
rfe_adhd = RFE(estimator=estimator, n_features_to_select=150)
rfe_adhd.fit(X_filtered, y.iloc[:, 0])
features_adhd = X_filtered.columns[rfe_adhd.get_support()]
ranks_adhd = rfe_adhd.ranking_[rfe_adhd.get_support()]
adhd_df = pd.DataFrame({'Feature': features_adhd, 'Rank_ADHD': ranks_adhd})

# 2. Fit RFE on Sex target
rfe_sex = RFE(estimator=estimator, n_features_to_select=150)
rfe_sex.fit(X_filtered, y.iloc[:, 1])
features_sex = X_filtered.columns[rfe_sex.get_support()]
ranks_sex = rfe_sex.ranking_[rfe_sex.get_support()]
sex_df = pd.DataFrame({'Feature': features_sex, 'Rank_Sex': ranks_sex})

# %%
# 3. Find common features
common_features_RFE = set(features_adhd).intersection(set(features_sex))

# 4. Merge and display scores (variation 2)
common_df = pd.merge(adhd_df, sex_df, on='Feature')
print(" Common Selected Features by RFE:")
print(common_df.sort_values(by=['Rank_ADHD', 'Rank_Sex']))

# 5. Only names (variation 1)
print("\n Common Feature Names:")
print(list(common_df['Feature']))
print(common_df.shape)
# Out:
#  Common Selected Features by RFE:
#                         Feature  Rank_ADHD  Rank_Sex
# 0                        PC_701          1         1
# 1                        PC_569          1         1
# 2                        PC_506          1         1
# 3                         PC_95          1         1
# 4                        PC_319          1         1
# ..                          ...        ...       ...
# 129                      PC_586          1         1
# 130  SDQ_SDQ_Difficulties_Total          1         1
# 131                      PC_548          1         1
# 132                      PC_412          1         1
# 133                      PC_481          1         1
#
# [134 rows x 3 columns]
#
#  Common Feature Names:
# ['PC_701', 'PC_569', 'PC_506', 'PC_95', 'PC_319', 'PC_708', 'PC_120', 'PC_28', 'PC_184', 'PC_98', 'PC_275', 'PC_576', 'PC_177', 'PC_587', 'PC_65', 'PC_552', 'PC_141', 'PC_391', 'PC_338', 'PC_43', 'PC_392', 'PC_268', 'PC_396', 'PC_452', 'PC_8', 'PC_35', 'PC_78', 'PC_303', 'PC_519', 'PC_149', 'PC_85', 'PC_619', 'PC_403', 'PC_178', 'PC_507', 'PC_475', 'PC_44', 'PC_240', 'PC_135', 'PC_664', 'PC_256', 'PC_333', 'PC_124', 'PC_233', 'PC_133', 'PC_166', 'PC_350', 'PC_597', 'PC_15', 'PC_502', 'PC_633', 'PC_429', 'PC_185', 'PC_239', 'PC_634', 'PC_33', 'PC_337', 'PC_360', 'PC_592', 'PC_549', 'PC_108', 'PC_626', 'PC_398', 'PC_524', 'PC_666', 'PC_22', 'PC_683', 'PC_210', 'PC_523', 'PC_109', 'PC_494', 'PC_226', 'PC_651', 'PC_492', 'PC_667', 'PC_581', 'PC_588', 'SDQ_SDQ_Externalizing', 'PC_600', 'PC_559', 'PC_142', 'PC_622', 'SDQ_SDQ_Hyperactivity', 'PC_433', 'PC_298', 'PC_680', 'PC_75', 'PC_349', 'PC_305', 'PC_674', 'PC_504', 'PC_232', 'PC_517', 'PC_604', 'PC_406', 'PC_182', 'PC_438', 'PC_237', 'PC_129', 'PC_32', 'PC_285', 'PC_81', 'PC_217', 'PC_490', 'PC_557', 'PC_158', 'PC_564', 'SDQ_SDQ_Prosocial', 'PC_36', 'PC_249', 'PC_243', 'PC_125', 'PC_493', 'PC_525', 'PC_200', 'PC_594', 'PC_553', 'PC_411', 'PC_646', 'PC_422', 'PC_558', 'PC_181', 'PC_202', 'PC_421', 'PC_699', 'PC_190', 'PC_270', 'PC_608', 'PC_424', 'PC_586', 'SDQ_SDQ_Difficulties_Total', 'PC_548', 'PC_412', 'PC_481']
# (134, 3)

# %%
X_filtered_RFE = X[list(common_features_RFE)]
X_filtered_RFE
# Out:
#                   PC_701    PC_569    PC_506    PC_708     PC_95    PC_319  \
# participant_id
# 00aIpNTbG5uh   -0.885926  0.668147 -0.981937 -0.134540  0.495522  0.653002
# 00fV0OyyoLfw    0.497977 -0.371995  0.433324  0.337728 -1.140333 -0.661232
# 04X1eiS79T4B    0.757717 -0.259811 -0.057170  0.037636 -0.152809  0.499940
# 05ocQutkURd6    0.054950  0.718920 -0.481879  0.363878  0.277905  0.123407
# 06YUNBA9ZRLq    0.547674 -0.716660  0.323613 -0.324686 -0.366564  0.140074
# ...                  ...       ...       ...       ...       ...       ...
# zpU7rEseBMH8   -0.249406  0.455074  0.256527  0.430341 -1.396686 -0.899611
# zpr8w4jCfVPe    0.190441  0.498044  0.221612 -0.037862 -0.722429  0.049094
# zwBG0rZ05Mcb    0.113720  0.321016 -0.086916 -0.122371 -0.861028  0.527487
# zwXD5v17Rx01   -0.314266 -1.173972 -0.232208  0.306661  0.450748  0.445068
# zwjJWCRzKhDz    0.512541 -0.500051  0.208450 -0.641685  0.098272 -0.285723
#
#                   PC_120     PC_28    PC_184     PC_98  ...    PC_699  \
# participant_id                                          ...
# 00aIpNTbG5uh   -0.389222 -0.576976  0.346141 -1.324826  ... -0.404643
# 00fV0OyyoLfw   -0.388142  2.356136 -1.095743 -0.691694  ... -1.034934
# 04X1eiS79T4B   -1.116080 -0.356987  0.741482 -1.208859  ...  0.382100
# 05ocQutkURd6   -0.965560 -0.956340  0.608650  0.270865  ... -0.087300
# 06YUNBA9ZRLq    0.287860  1.822979 -1.034526  1.777805  ... -0.439174
# ...                  ...       ...       ...       ...  ...       ...
# zpU7rEseBMH8    0.198835  1.623336 -1.344495 -0.044578  ... -0.576727
# zpr8w4jCfVPe    1.523251 -0.658448 -0.743944 -0.137535  ...  0.644565
# zwBG0rZ05Mcb   -0.947304 -0.748002  0.087103  0.010702  ... -0.254207
# zwXD5v17Rx01    0.926144  1.558243  1.173300  0.632484  ...  0.238254
# zwjJWCRzKhDz    0.290275 -1.067299  0.243268 -0.218967  ... -0.464611
#
#                   PC_190    PC_270    PC_608    PC_424    PC_586  \
# participant_id
# 00aIpNTbG5uh    1.339054  0.901018  0.752034  0.833928  0.182658
# 00fV0OyyoLfw    1.253018 -0.483971 -0.035371 -0.457536  0.135948
# 04X1eiS79T4B    0.921249 -0.106919 -0.802347  0.677101  0.602827
# 05ocQutkURd6    0.784159  0.257201  0.258233 -0.304691 -0.197279
# 06YUNBA9ZRLq   -0.166389  1.369513  0.266904  1.193239  0.118456
# ...                  ...       ...       ...       ...       ...
# zpU7rEseBMH8    1.423130 -0.238826  0.656437 -1.356682 -0.166307
# zpr8w4jCfVPe    0.644973 -0.365491 -0.080516  0.485095 -0.629223
# zwBG0rZ05Mcb    0.271796  0.029490  0.205248 -0.553610  0.369178
# zwXD5v17Rx01   -0.626284  1.208717 -0.319629 -1.741322  1.690599
# zwjJWCRzKhDz    0.512734 -0.243495  0.374271 -0.124781 -0.178560
#
#                 SDQ_SDQ_Difficulties_Total    PC_548    PC_412    PC_481
# participant_id
# 00aIpNTbG5uh                          17.0 -0.213999 -0.391421 -0.115218
# 00fV0OyyoLfw                          20.0  0.681074  1.422336  0.209462
# 04X1eiS79T4B                          24.0 -0.578763 -0.522436  0.753116
# 05ocQutkURd6                           5.0  0.096809  1.033389 -0.721753
# 06YUNBA9ZRLq                          23.0 -0.642111  0.123385  0.284133
# ...                                    ...       ...       ...       ...
# zpU7rEseBMH8                           8.0 -0.740099 -1.115198  0.325893
# zpr8w4jCfVPe                          15.0 -0.174393  0.999876 -0.771119
# zwBG0rZ05Mcb                          10.0  0.460728  0.193762  0.418423
# zwXD5v17Rx01                           5.0  0.223560  0.186028  0.310540
# zwjJWCRzKhDz                          20.0 -0.671756  0.074007 -0.274793
#
# [1213 rows x 134 columns]

# %%
intersection = set(common_features_RFE).intersection(set(common_features))
print(intersection)
# Out:
# {'PC_701', 'PC_569', 'PC_506', 'PC_708', 'PC_95', 'PC_319', 'PC_120', 'PC_28', 'PC_184', 'PC_98', 'PC_275', 'PC_576', 'PC_177', 'PC_587', 'PC_65', 'PC_552', 'PC_141', 'PC_391', 'PC_338', 'PC_43', 'PC_392', 'PC_268', 'PC_396', 'PC_452', 'PC_8', 'PC_35', 'PC_78', 'PC_303', 'PC_519', 'PC_149', 'PC_85', 'PC_619', 'PC_403', 'PC_178', 'PC_475', 'PC_507', 'PC_44', 'PC_664', 'PC_240', 'PC_135', 'PC_256', 'PC_333', 'PC_124', 'PC_233', 'PC_133', 'PC_166', 'PC_350', 'PC_597', 'PC_15', 'PC_502', 'PC_633', 'PC_429', 'PC_185', 'PC_239', 'PC_634', 'PC_33', 'PC_337', 'PC_360', 'PC_592', 'PC_549', 'PC_108', 'PC_626', 'PC_398', 'PC_524', 'PC_666', 'PC_22', 'PC_683', 'PC_210', 'PC_523', 'PC_109', 'PC_494', 'PC_226', 'PC_651', 'PC_492', 'PC_667', 'PC_581', 'PC_588', 'SDQ_SDQ_Externalizing', 'PC_600', 'PC_559', 'PC_142', 'PC_622', 'SDQ_SDQ_Hyperactivity', 'PC_433', 'PC_298', 'PC_680', 'PC_75', 'PC_349', 'PC_305', 'PC_674', 'PC_504', 'PC_232', 'PC_517', 'PC_604', 'PC_406', 'PC_182', 'PC_438', 'PC_237', 'PC_129', 'PC_32', 'PC_285', 'PC_81', 'PC_217', 'PC_490', 'PC_557', 'PC_158', 'PC_564', 'SDQ_SDQ_Prosocial', 'PC_36', 'PC_249', 'PC_243', 'PC_125', 'PC_493', 'PC_525', 'PC_200', 'PC_594', 'PC_553', 'PC_411', 'PC_646', 'PC_422', 'PC_558', 'PC_181', 'PC_202', 'PC_421', 'PC_699', 'PC_190', 'PC_270', 'PC_608', 'PC_424', 'PC_586', 'SDQ_SDQ_Difficulties_Total', 'PC_548', 'PC_412', 'PC_481'}

# %% [markdown]
# ### logestic reg

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel

# L1 model
logreg = LogisticRegression(penalty='l1', solver='liblinear')

# ADHD target (y[:, 0])
sfm_adhd = SelectFromModel(logreg)
sfm_adhd.fit(X_filtered, y.iloc[:, 0])
mask_adhd = sfm_adhd.get_support()
features_adhd = X_filtered.columns[mask_adhd]

# SEX target (y[:, 1])
sfm_sex = SelectFromModel(logreg)
sfm_sex.fit(X_filtered, y.iloc[:, 1])
mask_sex = sfm_sex.get_support()
features_sex = X_filtered.columns[mask_sex]

# %%
# 🟰 Common features
common_features = features_adhd.intersection(features_sex)

# Display
print("Number of common features:", len(common_features))
print("Common features:\n", common_features)
# Out:
# Number of common features: 147
# Common features:
#  Index(['PC_387', 'PC_257', 'PC_85', 'PC_167', 'PC_120', 'PC_394', 'PC_679',
#        'PC_98', 'PC_421', 'PC_299',
#        ...
#        'PC_49', 'PC_33', 'PC_233', 'PC_524', 'PC_490', 'SDQ_SDQ_Peer_Problems',
#        'PC_256', 'PC_588', 'PC_319', 'PC_504'],
#       dtype='object', length=147)

# %%
X_filtered_RFE = X[list(common_features_RFE)]
X_filtered_RFE

# %%
# Fit Logistic Regression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='liblinear', max_iter=1000)
model.fit(X_filtered, y.iloc[:, 0])  # ADHD target as example

# Get absolute coefficients and their feature names
coefficients = np.abs(model.coef_[0])
features = X_filtered.columns

# Create a DataFrame for easy sorting
coef_df = pd.DataFrame({'Feature': features, 'Absolute_Coefficient': coefficients})
top_coef_df = coef_df.sort_values(by='Absolute_Coefficient', ascending=False).head(20)

# Plot
plt.figure(figsize=(10, 6))
plt.barh(top_coef_df['Feature'][::-1], top_coef_df['Absolute_Coefficient'][::-1])
plt.xlabel('Absolute Coefficient')
plt.title('Top 20 Features (ADHD) by Absolute Logistic Regression Coefficients')
plt.tight_layout()
plt.show()

# %%
# Fit Logistic Regression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='liblinear', max_iter=1000)
model.fit(X_filtered, y.iloc[:, 1])  # SeX_F target as example

# Get absolute coefficients and their feature names
coefficients = np.abs(model.coef_[0])
features = X_filtered.columns

# Create a DataFrame for easy sorting
coef_df = pd.DataFrame({'Feature': features, 'Absolute_Coefficient': coefficients})
top_coef_df = coef_df.sort_values(by='Absolute_Coefficient', ascending=False).head(20)

# Plot
plt.figure(figsize=(10, 6))
plt.barh(top_coef_df['Feature'][::-1], top_coef_df['Absolute_Coefficient'][::-1])
plt.xlabel('Absolute Coefficient')
plt.title('Top 20 Features (Sex_F) by Absolute Logistic Regression Coefficients')
plt.tight_layout()
plt.show()

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import pandas as pd

# Initialize the model
estimator = LogisticRegression(solver='liblinear', penalty='l2', max_iter=1000)

# 1. Fit RFE on ADHD target
rfe_adhd = RFE(estimator=estimator, n_features_to_select=100)
rfe_adhd.fit(X_filtered, y.iloc[:, 0])
features_adhd = X_filtered.columns[rfe_adhd.get_support()]
ranks_adhd = rfe_adhd.ranking_[rfe_adhd.get_support()]
adhd_df = pd.DataFrame({'Feature': features_adhd, 'Rank_ADHD': ranks_adhd})

# 2. Fit RFE on Sex target
rfe_sex = RFE(estimator=estimator, n_features_to_select=100)
rfe_sex.fit(X_filtered, y.iloc[:, 1])
features_sex = X_filtered.columns[rfe_sex.get_support()]
ranks_sex = rfe_sex.ranking_[rfe_sex.get_support()]
sex_df = pd.DataFrame({'Feature': features_sex, 'Rank_Sex': ranks_sex})

# %%
# 3. Find common features
common_features_RFEl2 = set(features_adhd).intersection(set(features_sex))

# 4. Merge and display scores (variation 2)
common_df = pd.merge(adhd_df, sex_df, on='Feature')
print(" Common Selected Features by RFE:")
print(common_df.sort_values(by=['Rank_ADHD', 'Rank_Sex']))

# 5. Only names (variation 1)
print("\n Common Feature Names:")
print(list(common_df['Feature']))
print(common_df.shape)
# Out:
#  Common Selected Features by RFE:
#                   Feature  Rank_ADHD  Rank_Sex
# 0                  PC_701          1         1
# 1                  PC_708          1         1
# 2                  PC_679          1         1
# 3                  PC_275          1         1
# 4                  PC_587          1         1
# 5                   PC_65          1         1
# 6                  PC_552          1         1
# 7                  PC_141          1         1
# 8                  PC_391          1         1
# 9                  PC_452          1         1
# 10                 PC_149          1         1
# 11                 PC_491          1         1
# 12                 PC_619          1         1
# 13                 PC_403          1         1
# 14                 PC_178          1         1
# 15                 PC_507          1         1
# 16                 PC_240          1         1
# 17                 PC_664          1         1
# 18                 PC_166          1         1
# 19                 PC_350          1         1
# 20                 PC_633          1         1
# 21                 PC_185          1         1
# 22  SDQ_SDQ_Peer_Problems          1         1
# 23                 PC_626          1         1
# 24                 PC_666          1         1
# 25                 PC_609          1         1
# 26                 PC_683          1         1
# 27                 PC_226          1         1
# 28                 PC_651          1         1
# 29                 PC_581          1         1
# 30                 PC_600          1         1
# 31  SDQ_SDQ_Hyperactivity          1         1
# 32                 PC_433          1         1
# 33                 PC_680          1         1
# 34                 PC_305          1         1
# 35                 PC_504          1         1
# 36                 PC_232          1         1
# 37                 PC_604          1         1
# 38                 PC_406          1         1
# 39                 PC_438          1         1
# 40                 PC_237          1         1
# 41                 PC_285          1         1
# 42                 PC_158          1         1
# 43                 PC_564          1         1
# 44                 PC_563          1         1
# 45                 PC_525          1         1
# 46                 PC_594          1         1
# 47                 PC_411          1         1
# 48                 PC_394          1         1
# 49                 PC_646          1         1
# 50                 PC_422          1         1
# 51                 PC_181          1         1
# 52                 PC_421          1         1
# 53                 PC_699          1         1
# 54                 PC_270          1         1
# 55                 PC_586          1         1
# 56                 PC_548          1         1
# 57                 PC_412          1         1
# 58                 PC_481          1         1
#
#  Common Feature Names:
# ['PC_701', 'PC_708', 'PC_679', 'PC_275', 'PC_587', 'PC_65', 'PC_552', 'PC_141', 'PC_391', 'PC_452', 'PC_149', 'PC_491', 'PC_619', 'PC_403', 'PC_178', 'PC_507', 'PC_240', 'PC_664', 'PC_166', 'PC_350', 'PC_633', 'PC_185', 'SDQ_SDQ_Peer_Problems', 'PC_626', 'PC_666', 'PC_609', 'PC_683', 'PC_226', 'PC_651', 'PC_581', 'PC_600', 'SDQ_SDQ_Hyperactivity', 'PC_433', 'PC_680', 'PC_305', 'PC_504', 'PC_232', 'PC_604', 'PC_406', 'PC_438', 'PC_237', 'PC_285', 'PC_158', 'PC_564', 'PC_563', 'PC_525', 'PC_594', 'PC_411', 'PC_394', 'PC_646', 'PC_422', 'PC_181', 'PC_421', 'PC_699', 'PC_270', 'PC_586', 'PC_548', 'PC_412', 'PC_481']
# (59, 3)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import pandas as pd

# Initialize the model
estimator = LogisticRegression(solver='liblinear', penalty='l1', max_iter=1000)

# 1. Fit RFE on ADHD target
rfe_adhd = RFE(estimator=estimator, n_features_to_select=100)
rfe_adhd.fit(X_filtered, y.iloc[:, 0])
features_adhd = X_filtered.columns[rfe_adhd.get_support()]
ranks_adhd = rfe_adhd.ranking_[rfe_adhd.get_support()]
adhd_df = pd.DataFrame({'Feature': features_adhd, 'Rank_ADHD': ranks_adhd})

# 2. Fit RFE on Sex target
rfe_sex = RFE(estimator=estimator, n_features_to_select=100)
rfe_sex.fit(X_filtered, y.iloc[:, 1])
features_sex = X_filtered.columns[rfe_sex.get_support()]
ranks_sex = rfe_sex.ranking_[rfe_sex.get_support()]
sex_df = pd.DataFrame({'Feature': features_sex, 'Rank_Sex': ranks_sex})

# %%
# 3. Find common features
common_features_RFEl1 = set(features_adhd).intersection(set(features_sex))

# 4. Merge and display scores (variation 2)
common_df = pd.merge(adhd_df, sex_df, on='Feature')
print(" Common Selected Features by RFE:")
print(common_df.sort_values(by=['Rank_ADHD', 'Rank_Sex']))

# 5. Only names (variation 1)
print("\n Common Feature Names:")
print(list(common_df['Feature']))
print(common_df.shape)
# Out:
#  Common Selected Features by RFE:
#    Feature  Rank_ADHD  Rank_Sex
# 0   PC_701          1         1
# 1   PC_708          1         1
# 2   PC_275          1         1
# 3    PC_65          1         1
# 4   PC_552          1         1
# ..     ...        ...       ...
# 57  PC_270          1         1
# 58  PC_586          1         1
# 59  PC_548          1         1
# 60  PC_412          1         1
# 61  PC_481          1         1
#
# [62 rows x 3 columns]
#
#  Common Feature Names:
# ['PC_701', 'PC_708', 'PC_275', 'PC_65', 'PC_552', 'PC_141', 'PC_391', 'PC_452', 'PC_149', 'PC_491', 'PC_619', 'PC_403', 'PC_178', 'PC_507', 'PC_240', 'PC_664', 'PC_333', 'PC_124', 'PC_166', 'PC_350', 'PC_633', 'PC_185', 'SDQ_SDQ_Peer_Problems', 'PC_626', 'PC_666', 'PC_609', 'PC_683', 'Basic_Demos_Study_Site', 'PC_226', 'PC_651', 'PC_581', 'PC_600', 'SDQ_SDQ_Hyperactivity', 'PC_433', 'PC_680', 'PC_305', 'PC_504', 'PC_232', 'PC_604', 'PC_406', 'PC_182', 'PC_438', 'PC_285', 'PC_158', 'PC_564', 'PC_243', 'PC_563', 'PC_125', 'PC_525', 'PC_594', 'PC_411', 'PC_394', 'PC_646', 'PC_422', 'PC_181', 'PC_421', 'PC_699', 'PC_270', 'PC_586', 'PC_548', 'PC_412', 'PC_481']
# (62, 3)

# %% [markdown]
# ## Scaling

# %%
scaler = StandardScaler()
X_scaled = StandardScaler().fit_transform(X_filtered)
X_scaled_df = pd.DataFrame(X_scaled, columns=X_filtered.columns)

# %% [markdown]
# # Train-Test-Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.3, random_state=42)
print(f"X_train.shape {X_train.shape}          y_train.shape {y_train.shape} ")
print(f"X_test.shape {X_test.shape}            y_test.shape {y_test.shape} ")
# Out:
# X_train.shape (849, 171)          y_train.shape (849, 2)
# X_test.shape (364, 171)            y_test.shape (364, 2)

# %% [markdown]
# # Models

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import GridSearchCV
import joblib
import time
import os
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import RocCurveDisplay
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsClassifier()
multi_knn = MultiOutputClassifier(knn)

# %%
k_values = list(range(1,20))
param_grid = {
    'estimator__n_neighbors': k_values,
    'estimator__weights': ['uniform', 'distance'],
    'estimator__p': [1, 2]  # p=1 for Manhattan, p=2 for Euclidean
}

# %% [markdown]
# ### accuracy

# %%
grid_search = GridSearchCV(multi_knn, param_grid, cv=5, scoring='accuracy', n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/feature selection/(grid_search)multi_knn_scoring=accuracy.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 76 candidates, totalling 380 fits
# Model Saved
# Time taken: 0 hours, 0 minutes, 8 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=KNeighborsClassifier(n_neighbors=19, p=1))

# %%
best_model.get_params()
# Out:
# {'estimator__algorithm': 'auto',
#  'estimator__leaf_size': 30,
#  'estimator__metric': 'minkowski',
#  'estimator__metric_params': None,
#  'estimator__n_jobs': None,
#  'estimator__n_neighbors': 19,
#  'estimator__p': 1,
#  'estimator__weights': 'uniform',
#  'estimator': KNeighborsClassifier(n_neighbors=19, p=1),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.4499477897667942

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.53      0.73      0.62       121
#            1       0.83      0.68      0.75       243
#
#     accuracy                           0.70       364
#    macro avg       0.68      0.71      0.68       364
# weighted avg       0.73      0.70      0.71       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.70      0.95      0.80       254
#            1       0.32      0.05      0.09       110
#
#     accuracy                           0.68       364
#    macro avg       0.51      0.50      0.45       364
# weighted avg       0.58      0.68      0.59       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### multi_output_scorer

# %%
grid_search = GridSearchCV(multi_knn, param_grid, cv=5, scoring=multi_output_scorer, n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/feature selection/(grid_search)multi_knn_scoring=multi_output_scorer.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 76 candidates, totalling 380 fits
# Model Saved
# Time taken: 0 hours, 0 minutes, 3 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=KNeighborsClassifier(n_neighbors=19, p=1))

# %%
best_model.get_params()
# Out:
# {'estimator__algorithm': 'auto',
#  'estimator__leaf_size': 30,
#  'estimator__metric': 'minkowski',
#  'estimator__metric_params': None,
#  'estimator__n_jobs': None,
#  'estimator__n_neighbors': 19,
#  'estimator__p': 1,
#  'estimator__weights': 'uniform',
#  'estimator': KNeighborsClassifier(n_neighbors=19, p=1),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.6725791855203621

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.53      0.73      0.62       121
#            1       0.83      0.68      0.75       243
#
#     accuracy                           0.70       364
#    macro avg       0.68      0.71      0.68       364
# weighted avg       0.73      0.70      0.71       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.70      0.95      0.80       254
#            1       0.32      0.05      0.09       110
#
#     accuracy                           0.68       364
#    macro avg       0.51      0.50      0.45       364
# weighted avg       0.58      0.68      0.59       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### F1 Score

# %%
rid_search = GridSearchCV(multi_knn, param_grid, cv=5, scoring='f1_macro', n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/feature selection/(grid_search)multi_knn_scoring=f1_macro.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 76 candidates, totalling 380 fits
# Model Saved
# Time taken: 0 hours, 0 minutes, 3 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=KNeighborsClassifier(n_neighbors=19, p=1))

# %%
best_model.get_params()
# Out:
# {'estimator__algorithm': 'auto',
#  'estimator__leaf_size': 30,
#  'estimator__metric': 'minkowski',
#  'estimator__metric_params': None,
#  'estimator__n_jobs': None,
#  'estimator__n_neighbors': 19,
#  'estimator__p': 1,
#  'estimator__weights': 'uniform',
#  'estimator': KNeighborsClassifier(n_neighbors=19, p=1),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.6725791855203621

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.53      0.73      0.62       121
#            1       0.83      0.68      0.75       243
#
#     accuracy                           0.70       364
#    macro avg       0.68      0.71      0.68       364
# weighted avg       0.73      0.70      0.71       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.70      0.95      0.80       254
#            1       0.32      0.05      0.09       110
#
#     accuracy                           0.68       364
#    macro avg       0.51      0.50      0.45       364
# weighted avg       0.58      0.68      0.59       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Decision Trees

# %%
model = DecisionTreeClassifier(random_state=42)
multi_DT = MultiOutputClassifier(model)

# %%
param_grid = {
    'estimator__max_depth': [3, 5, 10, None],
    'estimator__min_samples_split': [2, 5],
    'estimator__min_samples_leaf': [1, 2],
    'estimator__max_features': ['sqrt', 'log2', None],
    'estimator__criterion': ['gini', 'entropy'],
    'estimator__class_weight': [None, 'balanced'],
}

# %% [markdown]
# ### accuracy

# %%
grid_search = GridSearchCV(multi_DT, param_grid, cv=5, scoring='accuracy', n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/feature selection/(grid_search)multi_DT_scoring=accuracy.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# Model Saved
# Time taken: 0 hours, 0 minutes, 8 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=DecisionTreeClassifier(criterion='entropy',
#                                                        max_depth=3,
#                                                        max_features='sqrt',
#                                                        random_state=42))

# %%
best_model.get_params()
# Out:
# {'estimator__ccp_alpha': 0.0,
#  'estimator__class_weight': None,
#  'estimator__criterion': 'entropy',
#  'estimator__max_depth': 3,
#  'estimator__max_features': 'sqrt',
#  'estimator__max_leaf_nodes': None,
#  'estimator__min_impurity_decrease': 0.0,
#  'estimator__min_samples_leaf': 1,
#  'estimator__min_samples_split': 2,
#  'estimator__min_weight_fraction_leaf': 0.0,
#  'estimator__monotonic_cst': None,
#  'estimator__random_state': 42,
#  'estimator__splitter': 'best',
#  'estimator': DecisionTreeClassifier(criterion='entropy', max_depth=3, max_features='sqrt',
#                         random_state=42),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.47356073790462927

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.63      0.64      0.63       121
#            1       0.82      0.81      0.81       243
#
#     accuracy                           0.75       364
#    macro avg       0.72      0.72      0.72       364
# weighted avg       0.75      0.75      0.75       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79       254
#            1       0.42      0.20      0.27       110
#
#     accuracy                           0.68       364
#    macro avg       0.57      0.54      0.53       364
# weighted avg       0.63      0.68      0.63       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### multi_output_scorer

# %%
grid_search = GridSearchCV(multi_DT, param_grid, cv=5, scoring=multi_output_scorer, n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/feature selection/(grid_search)multi_DT_scoring=multi_output_scorer.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# Model Saved
# Time taken: 0 hours, 0 minutes, 9 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=DecisionTreeClassifier(criterion='entropy',
#                                                        max_depth=3,
#                                                        max_features='sqrt',
#                                                        random_state=42))

# %%
best_model.get_params()
# Out:
# {'estimator__ccp_alpha': 0.0,
#  'estimator__class_weight': None,
#  'estimator__criterion': 'entropy',
#  'estimator__max_depth': 3,
#  'estimator__max_features': 'sqrt',
#  'estimator__max_leaf_nodes': None,
#  'estimator__min_impurity_decrease': 0.0,
#  'estimator__min_samples_leaf': 1,
#  'estimator__min_samples_split': 2,
#  'estimator__min_weight_fraction_leaf': 0.0,
#  'estimator__monotonic_cst': None,
#  'estimator__random_state': 42,
#  'estimator__splitter': 'best',
#  'estimator': DecisionTreeClassifier(criterion='entropy', max_depth=3, max_features='sqrt',
#                         random_state=42),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.6849634528367561

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.63      0.64      0.63       121
#            1       0.82      0.81      0.81       243
#
#     accuracy                           0.75       364
#    macro avg       0.72      0.72      0.72       364
# weighted avg       0.75      0.75      0.75       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79       254
#            1       0.42      0.20      0.27       110
#
#     accuracy                           0.68       364
#    macro avg       0.57      0.54      0.53       364
# weighted avg       0.63      0.68      0.63       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### f1_macro

# %%
grid_search = GridSearchCV(multi_DT, param_grid, cv=5, scoring='f1_macro', n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/feature selection/(grid_search)multi_DT_scoring=f1_macro.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# Model Saved
# Time taken: 0 hours, 0 minutes, 8 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=DecisionTreeClassifier(class_weight='balanced',
#                                                        max_depth=3,
#                                                        random_state=42))

# %%
best_model.get_params()
# Out:
# {'estimator__ccp_alpha': 0.0,
#  'estimator__class_weight': 'balanced',
#  'estimator__criterion': 'gini',
#  'estimator__max_depth': 3,
#  'estimator__max_features': None,
#  'estimator__max_leaf_nodes': None,
#  'estimator__min_impurity_decrease': 0.0,
#  'estimator__min_samples_leaf': 1,
#  'estimator__min_samples_split': 2,
#  'estimator__min_weight_fraction_leaf': 0.0,
#  'estimator__monotonic_cst': None,
#  'estimator__random_state': 42,
#  'estimator__splitter': 'best',
#  'estimator': DecisionTreeClassifier(class_weight='balanced', max_depth=3, random_state=42),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.6585016684141026

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.63      0.74      0.68       121
#            1       0.86      0.79      0.82       243
#
#     accuracy                           0.77       364
#    macro avg       0.74      0.76      0.75       364
# weighted avg       0.78      0.77      0.77       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.68      0.46      0.55       254
#            1       0.29      0.51      0.37       110
#
#     accuracy                           0.48       364
#    macro avg       0.49      0.48      0.46       364
# weighted avg       0.57      0.48      0.50       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Random Forests

# %%
RF = RandomForestClassifier(random_state=42)
multi_RF = MultiOutputClassifier(RF)
# Create the parameter grid based on the results of random search 
param_grid = {
    'estimator__n_estimators': [50, 100, 150],
    'estimator__max_depth': [2, 3, 5, 10, 15, 20],
    'estimator__min_samples_leaf': [1, 2, 3, 4, 5],
    'estimator__min_samples_split': [2, 5, 10, 15, 20, 25],
    'estimator__criterion': ['gini', 'entropy']
}

# %% [markdown]
# ### f1_macro

# %%
grid_search = GridSearchCV(multi_RF, param_grid, cv=5, scoring='f1_macro', n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/feature selection/(grid_search)multi_RF_scoring=f1_macro.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 1080 candidates, totalling 5400 fits
# Model Saved
# Time taken: 0 hours, 13 minutes, 29 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=RandomForestClassifier(criterion='entropy',
#                                                        max_depth=20,
#                                                        min_samples_leaf=2,
#                                                        min_samples_split=10,
#                                                        n_estimators=50,
#                                                        random_state=42))

# %%
best_model.get_params()
# Out:
# {'estimator__bootstrap': True,
#  'estimator__ccp_alpha': 0.0,
#  'estimator__class_weight': None,
#  'estimator__criterion': 'entropy',
#  'estimator__max_depth': 20,
#  'estimator__max_features': 'sqrt',
#  'estimator__max_leaf_nodes': None,
#  'estimator__max_samples': None,
#  'estimator__min_impurity_decrease': 0.0,
#  'estimator__min_samples_leaf': 2,
#  'estimator__min_samples_split': 10,
#  'estimator__min_weight_fraction_leaf': 0.0,
#  'estimator__monotonic_cst': None,
#  'estimator__n_estimators': 50,
#  'estimator__n_jobs': None,
#  'estimator__oob_score': False,
#  'estimator__random_state': 42,
#  'estimator__verbose': 0,
#  'estimator__warm_start': False,
#  'estimator': RandomForestClassifier(criterion='entropy', max_depth=20, min_samples_leaf=2,
#                         min_samples_split=10, n_estimators=50, random_state=42),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.4933240691823929

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.78      0.42      0.55       121
#            1       0.77      0.94      0.85       243
#
#     accuracy                           0.77       364
#    macro avg       0.78      0.68      0.70       364
# weighted avg       0.77      0.77      0.75       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82       254
#            1       0.67      0.02      0.04       110
#
#     accuracy                           0.70       364
#    macro avg       0.68      0.51      0.43       364
# weighted avg       0.69      0.70      0.58       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
# Define the model
log_reg = LogisticRegression(solver='liblinear', random_state=42)
multi_log = MultiOutputClassifier(log_reg)

# Define the parameter grid
param_grid = {
    'estimator__penalty': ['l1', 'l2'],
    'estimator__C': [0.001, 0.01, 0.1, 1, 10, 100],  # Regularization strength (lower means stronger regularization)
    'estimator__class_weight': [None, 'balanced']
}

# %% [markdown]
# ### accuracy

# %%
grid_search = GridSearchCV(multi_log, param_grid, cv=5, scoring='accuracy', n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/feature selection/(grid_search)multi_log_scoring=accuracy.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Model Saved
# Time taken: 0 hours, 0 minutes, 8 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=LogisticRegression(C=0.1, penalty='l1',
#                                                    random_state=42,
#                                                    solver='liblinear'))

# %%
best_model.get_params()
# Out:
# {'estimator__C': 0.1,
#  'estimator__class_weight': None,
#  'estimator__dual': False,
#  'estimator__fit_intercept': True,
#  'estimator__intercept_scaling': 1,
#  'estimator__l1_ratio': None,
#  'estimator__max_iter': 100,
#  'estimator__multi_class': 'auto',
#  'estimator__n_jobs': None,
#  'estimator__penalty': 'l1',
#  'estimator__random_state': 42,
#  'estimator__solver': 'liblinear',
#  'estimator__tol': 0.0001,
#  'estimator__verbose': 0,
#  'estimator__warm_start': False,
#  'estimator': LogisticRegression(C=0.1, penalty='l1', random_state=42, solver='liblinear'),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.5382805429864254

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.72      0.60      0.65       121
#            1       0.82      0.88      0.85       243
#
#     accuracy                           0.79       364
#    macro avg       0.77      0.74      0.75       364
# weighted avg       0.78      0.79      0.78       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80       254
#            1       0.50      0.31      0.38       110
#
#     accuracy                           0.70       364
#    macro avg       0.62      0.59      0.59       364
# weighted avg       0.67      0.70      0.67       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### multi_output_scorer

# %%
grid_search = GridSearchCV(multi_log, param_grid, cv=5, scoring=multi_output_scorer, n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/feature selection/(grid_search)multi_log_scoring=multi_output_scorer.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Model Saved
# Time taken: 0 hours, 0 minutes, 2 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=LogisticRegression(C=0.1, penalty='l1',
#                                                    random_state=42,
#                                                    solver='liblinear'))

# %%
best_model.get_params()
# Out:
# {'estimator__C': 0.1,
#  'estimator__class_weight': None,
#  'estimator__dual': False,
#  'estimator__fit_intercept': True,
#  'estimator__intercept_scaling': 1,
#  'estimator__l1_ratio': None,
#  'estimator__max_iter': 100,
#  'estimator__multi_class': 'auto',
#  'estimator__n_jobs': None,
#  'estimator__penalty': 'l1',
#  'estimator__random_state': 42,
#  'estimator__solver': 'liblinear',
#  'estimator__tol': 0.0001,
#  'estimator__verbose': 0,
#  'estimator__warm_start': False,
#  'estimator': LogisticRegression(C=0.1, penalty='l1', random_state=42, solver='liblinear'),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.7308806126000696

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.72      0.60      0.65       121
#            1       0.82      0.88      0.85       243
#
#     accuracy                           0.79       364
#    macro avg       0.77      0.74      0.75       364
# weighted avg       0.78      0.79      0.78       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80       254
#            1       0.50      0.31      0.38       110
#
#     accuracy                           0.70       364
#    macro avg       0.62      0.59      0.59       364
# weighted avg       0.67      0.70      0.67       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### f1_macro

# %%
grid_search = GridSearchCV(multi_log, param_grid, cv=5, scoring='f1_macro', n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/feature selection/(grid_search)multi_log_scoring=f1_macro.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model exists
# Model loaded

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=LogisticRegression(C=0.1,
#                                                    class_weight='balanced',
#                                                    penalty='l1',
#                                                    random_state=42,
#                                                    solver='liblinear'))

# %%
best_model.get_params()
# Out:
# {'estimator__C': 0.1,
#  'estimator__class_weight': 'balanced',
#  'estimator__dual': False,
#  'estimator__fit_intercept': True,
#  'estimator__intercept_scaling': 1,
#  'estimator__l1_ratio': None,
#  'estimator__max_iter': 100,
#  'estimator__multi_class': 'auto',
#  'estimator__n_jobs': None,
#  'estimator__penalty': 'l1',
#  'estimator__random_state': 42,
#  'estimator__solver': 'liblinear',
#  'estimator__tol': 0.0001,
#  'estimator__verbose': 0,
#  'estimator__warm_start': False,
#  'estimator': LogisticRegression(C=0.1, class_weight='balanced', penalty='l1',
#                     random_state=42, solver='liblinear'),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.665191933025555

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.59      0.75      0.66       121
#            1       0.86      0.74      0.79       243
#
#     accuracy                           0.74       364
#    macro avg       0.72      0.75      0.73       364
# weighted avg       0.77      0.74      0.75       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.78      0.64      0.70       254
#            1       0.41      0.58      0.48       110
#
#     accuracy                           0.62       364
#    macro avg       0.59      0.61      0.59       364
# weighted avg       0.67      0.62      0.63       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Neural Networks

# %% [markdown]
# - After multiple testing with different metrics (accuracy, multi_output_scorer and f1_macro ) it was decided to continue with only metric which is f1 score. This was based on confusion matrix and ROC curve.

# %% [markdown]
# # Testing stuff

# %% [markdown]
# ## more feaure selection (l2 vs l1)

# %% [markdown]
# Retaining the Logestic model on the data after :
# 1. Filtering using Uinvariate Feature selection.
# 2. RFE Selection (n_features_to_select=100) using logiestic regression with l2 penality on each label.
# 3. getting the common features.

# %%
Selected_features_l2 = ['PC_701', 'PC_708', 'PC_679', 'PC_275', 'PC_587', 'PC_65', 'PC_552', 'PC_141', 'PC_391', 'PC_452', 'PC_149',
                        'PC_491', 'PC_619', 'PC_403', 'PC_178', 'PC_507', 'PC_240', 'PC_664', 'PC_166', 'PC_350', 'PC_633', 'PC_185',
                        'SDQ_SDQ_Peer_Problems', 'PC_626', 'PC_666', 'PC_609', 'PC_683', 'PC_226', 'PC_651', 'PC_581', 'PC_600',
                        'SDQ_SDQ_Hyperactivity', 'PC_433', 'PC_680', 'PC_305', 'PC_504', 'PC_232', 'PC_604', 'PC_406', 'PC_438',
                        'PC_237', 'PC_285', 'PC_158', 'PC_564', 'PC_563', 'PC_525', 'PC_594', 'PC_411', 'PC_394', 'PC_646', 'PC_422',
                        'PC_181', 'PC_421', 'PC_699', 'PC_270', 'PC_586', 'PC_548', 'PC_412', 'PC_481']

X_filtered_l2 = X_filtered[Selected_features_l2]

# %%
len(Selected_features_l2)
# Out:
# 59

# %%
scaler = StandardScaler()
X_scaled = StandardScaler().fit_transform(X_filtered_l2)
X_scaled_df = pd.DataFrame(X_scaled, columns=X_filtered_l2.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.3, random_state=42)
print(f"X_train.shape {X_train.shape}          y_train.shape {y_train.shape} ")
print(f"X_test.shape {X_test.shape}            y_test.shape {y_test.shape} ")
# Out:
# X_train.shape (849, 59)          y_train.shape (849, 2)
# X_test.shape (364, 59)            y_test.shape (364, 2)

# %%
from sklearn.linear_model import LogisticRegression
# Define the model
log_reg = LogisticRegression(solver='liblinear', random_state=42)
multi_log = MultiOutputClassifier(log_reg)

# Define the parameter grid
param_grid = {
    'estimator__penalty': ['l1', 'l2'],
    'estimator__C': [0.001, 0.01, 0.1, 1, 10, 100],  # Regularization strength (lower means stronger regularization)
    'estimator__class_weight': [None, 'balanced']
}
grid_search = GridSearchCV(multi_log, param_grid, cv=5, scoring='f1_macro', n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/TEST/(grid_search)multi_log_scoring=f1_macro.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Model Saved
# Time taken: 0 hours, 0 minutes, 6 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=LogisticRegression(C=0.01,
#                                                    class_weight='balanced',
#                                                    random_state=42,
#                                                    solver='liblinear'))

# %%
best_model.get_params()
# Out:
# {'estimator__C': 0.01,
#  'estimator__class_weight': 'balanced',
#  'estimator__dual': False,
#  'estimator__fit_intercept': True,
#  'estimator__intercept_scaling': 1,
#  'estimator__l1_ratio': None,
#  'estimator__max_iter': 100,
#  'estimator__multi_class': 'auto',
#  'estimator__n_jobs': None,
#  'estimator__penalty': 'l2',
#  'estimator__random_state': 42,
#  'estimator__solver': 'liblinear',
#  'estimator__tol': 0.0001,
#  'estimator__verbose': 0,
#  'estimator__warm_start': False,
#  'estimator': LogisticRegression(C=0.01, class_weight='balanced', random_state=42,
#                     solver='liblinear'),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.6421602247015767

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.56      0.79      0.65       121
#            1       0.87      0.69      0.77       243
#
#     accuracy                           0.72       364
#    macro avg       0.71      0.74      0.71       364
# weighted avg       0.76      0.72      0.73       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.73      0.56      0.63       254
#            1       0.34      0.53      0.41       110
#
#     accuracy                           0.55       364
#    macro avg       0.53      0.54      0.52       364
# weighted avg       0.61      0.55      0.56       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# - It gave worse results we will try the features optained from the l1 variation

# %%
Selected_features_l1 = ['PC_701', 'PC_708', 'PC_275', 'PC_65', 'PC_552', 'PC_141', 'PC_391', 'PC_452', 'PC_149', 'PC_491',
                        'PC_619', 'PC_403', 'PC_178', 'PC_507', 'PC_240', 'PC_664', 'PC_333', 'PC_124', 'PC_166', 'PC_350',
                        'PC_633', 'PC_185', 'SDQ_SDQ_Peer_Problems', 'PC_626', 'PC_666', 'PC_609', 'PC_683', 'Basic_Demos_Study_Site',
                        'PC_226', 'PC_651', 'PC_581', 'PC_600', 'SDQ_SDQ_Hyperactivity', 'PC_433', 'PC_680', 'PC_305', 'PC_504', 'PC_232',
                        'PC_604', 'PC_406', 'PC_182', 'PC_438', 'PC_285', 'PC_158', 'PC_564', 'PC_243', 'PC_563', 'PC_125', 'PC_525',
                        'PC_594', 'PC_411', 'PC_394', 'PC_646', 'PC_422', 'PC_181', 'PC_421', 'PC_699', 'PC_270', 'PC_586', 'PC_548', 'PC_412', 'PC_481']

X_filtered_l1 = X_filtered[Selected_features_l1]

# %%
len(Selected_features_l1)
# Out:
# 62

# %%
scaler = StandardScaler()
X_scaled = StandardScaler().fit_transform(X_filtered_l1)
X_scaled_df = pd.DataFrame(X_scaled, columns=X_filtered_l1.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.3, random_state=42)
print(f"X_train.shape {X_train.shape}          y_train.shape {y_train.shape} ")
print(f"X_test.shape {X_test.shape}            y_test.shape {y_test.shape} ")
# Out:
# X_train.shape (849, 62)          y_train.shape (849, 2)
# X_test.shape (364, 62)            y_test.shape (364, 2)

# %%
from sklearn.linear_model import LogisticRegression
# Define the model
log_reg = LogisticRegression(solver='liblinear', random_state=42)
multi_log = MultiOutputClassifier(log_reg)

# Define the parameter grid
param_grid = {
    'estimator__penalty': ['l1', 'l2'],
    'estimator__C': [0.001, 0.01, 0.1, 1, 10, 100],  # Regularization strength (lower means stronger regularization)
    'estimator__class_weight': [None, 'balanced']
}
grid_search = GridSearchCV(multi_log, param_grid, cv=5, scoring='f1_macro', n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/TEST/l1(grid_search)multi_log_scoring=f1_macro.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Model Saved
# Time taken: 0 hours, 0 minutes, 0 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=LogisticRegression(C=0.1,
#                                                    class_weight='balanced',
#                                                    penalty='l1',
#                                                    random_state=42,
#                                                    solver='liblinear'))

# %%
best_model.get_params()
# Out:
# {'estimator__C': 0.1,
#  'estimator__class_weight': 'balanced',
#  'estimator__dual': False,
#  'estimator__fit_intercept': True,
#  'estimator__intercept_scaling': 1,
#  'estimator__l1_ratio': None,
#  'estimator__max_iter': 100,
#  'estimator__multi_class': 'auto',
#  'estimator__n_jobs': None,
#  'estimator__penalty': 'l1',
#  'estimator__random_state': 42,
#  'estimator__solver': 'liblinear',
#  'estimator__tol': 0.0001,
#  'estimator__verbose': 0,
#  'estimator__warm_start': False,
#  'estimator': LogisticRegression(C=0.1, class_weight='balanced', penalty='l1',
#                     random_state=42, solver='liblinear'),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.6457620793478589

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.58      0.79      0.67       121
#            1       0.87      0.72      0.79       243
#
#     accuracy                           0.74       364
#    macro avg       0.73      0.75      0.73       364
# weighted avg       0.78      0.74      0.75       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.74      0.55      0.63       254
#            1       0.34      0.55      0.42       110
#
#     accuracy                           0.55       364
#    macro avg       0.54      0.55      0.52       364
# weighted avg       0.62      0.55      0.57       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# - Almost the same as l2 which are both bad compared to the higher number of feature case in section 6.4

# %% [markdown]
# ## Using PCA on l1
# To further decrease it into 20 (or more) features

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

pcal1 = PCA().fit(X_filtered_l1)
plt.plot(np.cumsum(pcal1.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.show()

# %%
pcal1 = PCA(n_components=0.7)  # Keep 75% of the variance
reduced_datal1 = pcal1.fit_transform(X_filtered_l1)
reduced_datal1.shape
# Out:
# (1213, 23)

# %%
pca_columns = [f'PC_{i+1}' for i in range(reduced_datal1.shape[1])]

# Convert to DataFrame
reduced_df_l1 = pd.DataFrame(reduced_datal1, columns=pca_columns)
reduced_df_l1
# Out:
#           PC_1      PC_2      PC_3      PC_4      PC_5      PC_6      PC_7  \
# 0     2.248344 -1.388193  0.381834  1.535272 -0.340566 -0.921497 -0.380419
# 1     2.607973 -0.214027  0.171720 -1.012047 -0.705207 -0.013094  1.089705
# 2     3.147391  3.904301  0.334167 -0.823333 -0.739185 -0.272499  0.450397
# 3    -2.463011  0.730263  1.148566 -0.600966  0.514570  1.428756  1.009487
# 4     2.787892 -2.365106  0.293078 -1.199595 -0.923496  0.446017  0.233799
# ...        ...       ...       ...       ...       ...       ...       ...
# 1208  0.319501 -0.297437  1.746924 -1.225791  0.071918  2.350520 -2.544215
# 1209  2.048610  0.938613 -0.521314  1.508774  0.148350  1.140147  0.282898
# 1210 -0.562848 -0.012257 -0.383651 -0.864344 -1.313019 -0.042653 -0.072391
# 1211 -3.261122 -1.004197 -1.961684 -1.053730 -1.085164  0.136789  0.112580
# 1212  2.236718 -1.306261 -2.289715  1.532769 -0.627342 -1.230575 -0.411528
#
#           PC_8      PC_9     PC_10  ...     PC_14     PC_15     PC_16  \
# 0    -0.506140 -0.127379 -0.091261  ... -1.583356 -0.141064  0.206644
# 1    -0.593721  1.846107  0.142906  ... -0.667019  0.370218 -1.041563
# 2    -0.552380 -0.154507 -0.952851  ...  0.666955 -0.197511  0.248083
# 3     0.575715  0.838174 -0.621860  ...  0.596581 -0.698733  0.024174
# 4    -0.494275  0.305445  1.106758  ... -0.299868 -0.369007  1.282265
# ...        ...       ...       ...  ...       ...       ...       ...
# 1208 -0.098815 -0.682861 -0.453658  ... -2.294655 -1.081666  0.232654
# 1209  0.158013 -0.319782 -0.085894  ... -0.208938 -1.252042 -0.585277
# 1210 -0.754579  0.915990 -0.380306  ... -1.627365  0.637786 -0.602077
# 1211 -1.083440 -1.502446  0.090782  ... -1.679846  0.463239 -0.782417
# 1212  0.243390 -0.921759 -1.161047  ...  0.127560  0.326670  0.324351
#
#          PC_17     PC_18     PC_19     PC_20     PC_21     PC_22     PC_23
# 0    -0.545351 -1.507110  0.943138 -0.452443  0.768423 -0.890176  1.042498
# 1     0.719497 -0.586497 -0.472010 -0.851408  0.494090  1.450123 -0.431920
# 2    -1.563225  0.559882 -0.119233 -1.025651  0.342192 -1.336209 -0.649850
# 3     0.713483 -0.115099  0.229267  1.103057 -0.902513 -0.068719 -0.847236
# 4     1.027947  1.289219  1.363531  0.539307 -0.414920  1.316174  0.201489
# ...        ...       ...       ...       ...       ...       ...       ...
# 1208  0.082404  0.279939 -0.256400  0.318323  0.519740 -0.729730 -0.532872
# 1209 -0.066854  0.456089 -0.364370 -1.023622 -0.021953  0.408436  0.760971
# 1210 -0.181036  1.158182 -0.012241  1.174908  0.273285 -0.719726  0.016233
# 1211 -0.224849 -0.092717  1.191398  0.745202  0.958442  0.103418 -0.465002
# 1212  0.187783  0.089744 -0.210611 -1.005256  0.133258  0.606697  0.198523
#
# [1213 rows x 23 columns]

# %%
scaler = StandardScaler()
X_scaled = StandardScaler().fit_transform(reduced_df_l1)
X_scaled_df = pd.DataFrame(X_scaled, columns=reduced_df_l1.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.3, random_state=42)
print(f"X_train.shape {X_train.shape}          y_train.shape {y_train.shape} ")
print(f"X_test.shape {X_test.shape}            y_test.shape {y_test.shape} ")
# Out:
# X_train.shape (849, 23)          y_train.shape (849, 2)
# X_test.shape (364, 23)            y_test.shape (364, 2)

# %%
from sklearn.linear_model import LogisticRegression
# Define the model
log_reg = LogisticRegression(solver='liblinear', random_state=42)
multi_log = MultiOutputClassifier(log_reg)

# Define the parameter grid
param_grid = {
    'estimator__penalty': ['l1', 'l2'],
    'estimator__C': [0.001, 0.01, 0.1, 1, 10, 100],  # Regularization strength (lower means stronger regularization)
    'estimator__class_weight': [None, 'balanced']
}
grid_search = GridSearchCV(multi_log, param_grid, cv=5, scoring='f1_macro', n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/TEST/PCA(grid_search)multi_log_scoring=f1_macro.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Model Saved
# Time taken: 0 hours, 0 minutes, 7 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=LogisticRegression(C=0.1,
#                                                    class_weight='balanced',
#                                                    penalty='l1',
#                                                    random_state=42,
#                                                    solver='liblinear'))

# %%
best_model.get_params()
# Out:
# {'estimator__C': 0.1,
#  'estimator__class_weight': 'balanced',
#  'estimator__dual': False,
#  'estimator__fit_intercept': True,
#  'estimator__intercept_scaling': 1,
#  'estimator__l1_ratio': None,
#  'estimator__max_iter': 100,
#  'estimator__multi_class': 'auto',
#  'estimator__n_jobs': None,
#  'estimator__penalty': 'l1',
#  'estimator__random_state': 42,
#  'estimator__solver': 'liblinear',
#  'estimator__tol': 0.0001,
#  'estimator__verbose': 0,
#  'estimator__warm_start': False,
#  'estimator': LogisticRegression(C=0.1, class_weight='balanced', penalty='l1',
#                     random_state=42, solver='liblinear'),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.6536807698781355

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.56      0.77      0.65       121
#            1       0.86      0.70      0.77       243
#
#     accuracy                           0.73       364
#    macro avg       0.71      0.74      0.71       364
# weighted avg       0.76      0.73      0.73       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.76      0.58      0.66       254
#            1       0.37      0.57      0.45       110
#
#     accuracy                           0.58       364
#    macro avg       0.57      0.58      0.56       364
# weighted avg       0.64      0.58      0.60       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# - slight improvement on using l1 only but still worse that sec 6.4 which had more features with less layers of selections

# %% [markdown]
# ## Using PCA on log_model of section 6.4.3

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

pcal1 = PCA().fit(X_filtered)
plt.plot(np.cumsum(pcal1.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.show()

# %%
pcal1 = PCA(n_components=0.8)  # Keep 75% of the variance
reduced_datal1 = pcal1.fit_transform(X_filtered)
reduced_datal1.shape
# Out:
# (1213, 52)

# %%
pca_columns = [f'PC_{i+1}' for i in range(reduced_datal1.shape[1])]

# Convert to DataFrame
reduced_df_l1 = pd.DataFrame(reduced_datal1, columns=pca_columns)
reduced_df_l1
# Out:
#            PC_1      PC_2      PC_3      PC_4      PC_5      PC_6      PC_7  \
# 0      6.167711 -1.663607 -2.079897 -2.638991 -1.676415 -3.279053 -0.500845
# 1     10.164292 -1.563765 -0.046359  1.092563  1.148533 -0.510116 -1.198562
# 2     15.409946  7.556787  2.505819  1.887743 -2.631706 -0.069211  3.000613
# 3     -9.861136  1.126196 -0.061913 -0.440868  0.332109  0.843398 -3.353536
# 4     14.801841 -2.548281  2.898113  2.504928  0.329693 -0.768474 -1.239427
# ...         ...       ...       ...       ...       ...       ...       ...
# 1208  -4.421312 -1.341851 -1.521828 -1.874698  0.822164 -0.585464  2.285890
# 1209   3.219112  2.411971 -0.931155  3.253925 -4.367298  0.922521  0.621711
# 1210  -3.356666  1.406577  1.041994 -1.280299  4.001024 -0.962677 -1.645929
# 1211  -9.769141 -2.768411 -0.649303 -2.496308 -0.955611  3.001717 -0.796399
# 1212   9.960388 -1.743028 -2.890874 -2.251815 -1.277101 -1.363575 -2.595274
#
#           PC_8      PC_9     PC_10  ...     PC_43     PC_44     PC_45  \
# 0    -0.343436 -0.527396 -3.775461  ... -0.073160 -0.307388 -0.653487
# 1    -1.125034 -2.271198  1.032373  ...  1.919629  0.196442  0.350067
# 2    -0.979409  1.016139  1.172335  ... -0.285524 -0.841102  0.793153
# 3     3.852892  1.342937  1.277529  ...  0.510742 -0.722645 -1.110635
# 4     4.627050 -2.156091  0.251017  ...  0.395265  1.423326 -0.554601
# ...        ...       ...       ...  ...       ...       ...       ...
# 1208  0.044411 -1.158242  0.989938  ... -0.372329 -0.172797  1.951359
# 1209 -1.228268  2.326274  2.738593  ... -0.351911 -0.335631  0.228138
# 1210  0.185012  0.858866  0.229391  ...  0.607932 -0.412428  0.548075
# 1211 -0.067072 -1.336521  1.782543  ... -1.060113  0.468759  0.869333
# 1212  0.509861 -0.522972 -2.964876  ... -0.873177 -1.196412 -1.228806
#
#          PC_46     PC_47     PC_48     PC_49     PC_50     PC_51     PC_52
# 0    -0.049035  1.154426 -2.035602  0.314404 -1.032680  0.863394 -0.976992
# 1    -0.123031  0.913274 -0.372673 -0.535407 -0.500489  1.162337  0.522916
# 2     0.978151 -0.335502 -1.035185  1.360330  0.855953  0.141559  0.398789
# 3     1.072076 -0.399872  0.068031  0.871367  0.424805  0.854789  1.065983
# 4     0.174592  0.552059 -0.891532 -1.627685  0.438174  1.235583  0.301164
# ...        ...       ...       ...       ...       ...       ...       ...
# 1208  1.203527  0.362750 -1.360329 -0.985750 -1.515021  1.287408 -1.419843
# 1209 -0.539007  1.244770 -0.045156 -0.412252 -0.451004  0.845980  1.459608
# 1210 -0.589698  1.230056 -0.434745  0.217659 -1.884331 -0.109834 -0.171403
# 1211 -0.790076 -0.293849 -1.112704  0.706907 -1.884186 -0.946016  0.176016
# 1212 -0.792205 -0.804294 -1.143720 -0.394511  0.127436  0.877519 -0.596908
#
# [1213 rows x 52 columns]

# %%
scaler = StandardScaler()
X_scaled = StandardScaler().fit_transform(reduced_df_l1)
X_scaled_df = pd.DataFrame(X_scaled, columns=reduced_df_l1.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.3, random_state=42)
print(f"X_train.shape {X_train.shape}          y_train.shape {y_train.shape} ")
print(f"X_test.shape {X_test.shape}            y_test.shape {y_test.shape} ")
# Out:
# X_train.shape (849, 52)          y_train.shape (849, 2)
# X_test.shape (364, 52)            y_test.shape (364, 2)

# %%
grid_search = GridSearchCV(multi_log, param_grid, cv=5, scoring='f1_macro', n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/TEST/PCA on best model (sec.6.4.3)(grid_search)multi_log_scoring=f1_macro.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Model Saved
# Time taken: 0 hours, 0 minutes, 5 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=LogisticRegression(C=1, class_weight='balanced',
#                                                    penalty='l1',
#                                                    random_state=42,
#                                                    solver='liblinear'))

# %%
best_model.get_params()
# Out:
# {'estimator__C': 1,
#  'estimator__class_weight': 'balanced',
#  'estimator__dual': False,
#  'estimator__fit_intercept': True,
#  'estimator__intercept_scaling': 1,
#  'estimator__l1_ratio': None,
#  'estimator__max_iter': 100,
#  'estimator__multi_class': 'auto',
#  'estimator__n_jobs': None,
#  'estimator__penalty': 'l1',
#  'estimator__random_state': 42,
#  'estimator__solver': 'liblinear',
#  'estimator__tol': 0.0001,
#  'estimator__verbose': 0,
#  'estimator__warm_start': False,
#  'estimator': LogisticRegression(C=1, class_weight='balanced', penalty='l1', random_state=42,
#                     solver='liblinear'),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.6770384653994767

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.58      0.73      0.64       121
#            1       0.84      0.74      0.79       243
#
#     accuracy                           0.73       364
#    macro avg       0.71      0.73      0.72       364
# weighted avg       0.76      0.73      0.74       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.78      0.65      0.71       254
#            1       0.42      0.58      0.49       110
#
#     accuracy                           0.63       364
#    macro avg       0.60      0.62      0.60       364
# weighted avg       0.67      0.63      0.64       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### PCA =0.7

# %%
pcal1 = PCA(n_components=0.7)  # Keep 75% of the variance
reduced_datal1 = pcal1.fit_transform(X_filtered)
reduced_datal1.shape
# Out:
# (1213, 28)

# %%
pca_columns = [f'PC_{i+1}' for i in range(reduced_datal1.shape[1])]

# Convert to DataFrame
reduced_df_l1 = pd.DataFrame(reduced_datal1, columns=pca_columns)
reduced_df_l1
# Out:
#            PC_1      PC_2      PC_3      PC_4      PC_5      PC_6      PC_7  \
# 0      6.167711 -1.663607 -2.079897 -2.638991 -1.676415 -3.279053 -0.500845
# 1     10.164292 -1.563765 -0.046359  1.092563  1.148533 -0.510116 -1.198562
# 2     15.409946  7.556787  2.505819  1.887743 -2.631706 -0.069211  3.000613
# 3     -9.861136  1.126196 -0.061913 -0.440868  0.332109  0.843398 -3.353536
# 4     14.801841 -2.548281  2.898113  2.504928  0.329693 -0.768474 -1.239427
# ...         ...       ...       ...       ...       ...       ...       ...
# 1208  -4.421312 -1.341851 -1.521828 -1.874698  0.822164 -0.585464  2.285890
# 1209   3.219112  2.411971 -0.931155  3.253925 -4.367298  0.922521  0.621711
# 1210  -3.356666  1.406577  1.041994 -1.280299  4.001024 -0.962677 -1.645929
# 1211  -9.769141 -2.768411 -0.649303 -2.496308 -0.955611  3.001717 -0.796399
# 1212   9.960388 -1.743028 -2.890874 -2.251815 -1.277101 -1.363575 -2.595274
#
#           PC_8      PC_9     PC_10  ...     PC_19     PC_20     PC_21  \
# 0    -0.343436 -0.527396 -3.775461  ...  0.534486  1.807585 -0.493593
# 1    -1.125034 -2.271198  1.032373  ...  0.319590 -0.472803  0.787796
# 2    -0.979409  1.016139  1.172335  ...  0.326551 -1.390356 -0.154037
# 3     3.852892  1.342937  1.277529  ...  0.936256  0.102062 -1.215954
# 4     4.627050 -2.156091  0.251017  ...  0.502299 -0.425396 -0.789571
# ...        ...       ...       ...  ...       ...       ...       ...
# 1208  0.044411 -1.158242  0.989938  ...  1.591719 -0.850692  0.083950
# 1209 -1.228268  2.326274  2.738593  ... -0.781088 -0.572631 -1.244258
# 1210  0.185012  0.858866  0.229391  ... -0.388837 -0.590146  1.382710
# 1211 -0.067072 -1.336521  1.782543  ... -1.860883  0.245935 -2.377710
# 1212  0.509861 -0.522972 -2.964876  ... -1.930063  3.398924 -1.047105
#
#          PC_22     PC_23     PC_24     PC_25     PC_26     PC_27     PC_28
# 0    -1.205908  1.092036 -0.391575 -0.719957 -0.763381  0.966333 -1.121249
# 1     1.902254 -1.119889  0.343297  0.128715 -0.893874  0.014653 -0.425753
# 2    -0.806575  0.372175  0.165622 -0.883338 -1.093204  0.043828  1.104003
# 3     0.482264 -0.110955 -0.036072  1.652543 -0.002034  0.786883  1.143162
# 4     0.140041  1.028933 -0.435729  0.360280  0.148884 -1.728554  2.212387
# ...        ...       ...       ...       ...       ...       ...       ...
# 1208  2.948491  0.308008  0.161166 -0.033583 -0.267833 -0.151716 -0.881599
# 1209  1.970205  1.623629 -0.179705 -1.158747 -0.072076  0.133823 -1.839339
# 1210  1.104712  0.187788  1.631878 -0.363479 -0.577821 -0.610925  0.081721
# 1211  1.280032  1.325126  1.599946 -0.237230  0.218382 -0.116266  1.369070
# 1212  0.705397 -0.194409 -0.013341 -0.438926 -0.696939 -0.336843 -0.437237
#
# [1213 rows x 28 columns]

# %%
scaler = StandardScaler()
X_scaled = StandardScaler().fit_transform(reduced_df_l1)
X_scaled_df = pd.DataFrame(X_scaled, columns=reduced_df_l1.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.3, random_state=42)
print(f"X_train.shape {X_train.shape}          y_train.shape {y_train.shape} ")
print(f"X_test.shape {X_test.shape}            y_test.shape {y_test.shape} ")
# Out:
# X_train.shape (849, 28)          y_train.shape (849, 2)
# X_test.shape (364, 28)            y_test.shape (364, 2)

# %%
grid_search = GridSearchCV(multi_log, param_grid, cv=5, scoring='f1_macro', n_jobs=-1, verbose=2)

# %%
# Specify the file path where the grid search results are saved
file_path = "Models/TEST/PCA=0.7 on best model (sec.6.4.3)(grid_search)multi_log_scoring=f1_macro.pkl"

# Check if the file exists
if os.path.exists(file_path):
    print("Model exists")
    # Load the saved GridSearchCV object from the file
    grid_search = joblib.load(file_path)
    print("Model loaded")
else:
    print("Model Does not exist")
    # Start time measurement
    start_time = time.time()

    grid_search.fit(X_train, y_train)
    # End time measurement
    end_time = time.time()
    # Save the GridSearchCV object to a file
    joblib.dump(grid_search, file_path)
    time_taken=end_time-start_time
    print("Model Saved")
    hours, remainder = divmod(time_taken, 3600)
    minutes, seconds = divmod(remainder, 60)

    # Print the result
    print("Time taken: {} hours, {} minutes, {} seconds".format(int(hours), int(minutes), int(seconds)))
# Out:
# Model Does not exist
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Model Saved
# Time taken: 0 hours, 0 minutes, 6 seconds

# %%
best_model = grid_search.best_estimator_
best_model
# Out:
# MultiOutputClassifier(estimator=LogisticRegression(C=0.1,
#                                                    class_weight='balanced',
#                                                    random_state=42,
#                                                    solver='liblinear'))

# %%
best_model.get_params()
# Out:
# {'estimator__C': 0.1,
#  'estimator__class_weight': 'balanced',
#  'estimator__dual': False,
#  'estimator__fit_intercept': True,
#  'estimator__intercept_scaling': 1,
#  'estimator__l1_ratio': None,
#  'estimator__max_iter': 100,
#  'estimator__multi_class': 'auto',
#  'estimator__n_jobs': None,
#  'estimator__penalty': 'l2',
#  'estimator__random_state': 42,
#  'estimator__solver': 'liblinear',
#  'estimator__tol': 0.0001,
#  'estimator__verbose': 0,
#  'estimator__warm_start': False,
#  'estimator': LogisticRegression(C=0.1, class_weight='balanced', random_state=42,
#                     solver='liblinear'),
#  'n_jobs': None}

# %%
print("Best score:", grid_search.best_score_)
# Out:
# Best score: 0.6664016339787912

# %%
# Predict
y_pred = best_model.predict(X_test)

# Loop over each target
for i, target_name in enumerate(y_test.columns):
    print(f"\n--- Classification Report for Target: {target_name} ---")
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# --- Classification Report for Target: ADHD_Outcome ---
#               precision    recall  f1-score   support
#
#            0       0.59      0.74      0.66       121
#            1       0.85      0.74      0.80       243
#
#     accuracy                           0.74       364
#    macro avg       0.72      0.74      0.73       364
# weighted avg       0.77      0.74      0.75       364
#
#
# --- Classification Report for Target: Sex_F ---
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73       254
#            1       0.44      0.62      0.52       110
#
#     accuracy                           0.65       364
#    macro avg       0.62      0.64      0.62       364
# weighted avg       0.69      0.65      0.66       364

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    ConfusionMatrixDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"Confusion Matrix - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

for i, (ax, target_name) in enumerate(zip(axes, y_test.columns)):
    RocCurveDisplay.from_predictions(
        y_test.iloc[:, i],
        y_pred[:, i],
        ax=ax,
    )
    ax.set_title(f"RocCurve - {target_name}")
    ax.grid(False)

plt.tight_layout()
plt.show()
